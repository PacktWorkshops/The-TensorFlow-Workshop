# %% [markdown]
# NVIDIA Stock Prediction
#
# Steps to build stock prediction model
#
#
# *   Data Preprocessing
# *   Building the RNN
# *   Making the prediction and visualization

# %% [markdown]
# # **Data Preprocessing**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
#from google.colab import files
#uploaded = files.upload()

# %%
import io
#data = pd.read_csv(io.BytesIO(uploaded['NVDA.csv']))
data = pd.read_csv("https://raw.githubusercontent.com/PacktWorkshops/The-TensorFlow-Workshop/master/Chapter09/Exercise9.01/NVDA%20Exercise%209.1.csv")
# Dataset is now stored in a Pandas Dataframe

# %%
data.head()
# Out:
#          Date       Open       High    Low      Close  Adj Close   Volume
# 0  2015-07-22  19.650000  19.650000  19.17  19.410000  18.851749  8911800
# 1  2015-07-23  19.450001  19.940001  19.41  19.650000  19.084845  4247900
# 2  2015-07-24  19.790001  19.809999  19.34  19.420000  18.861464  4721100
# 3  2015-07-27  19.250000  19.530001  19.09  19.309999  18.754622  4810500
# 4  2015-07-28  19.360001  19.860001  19.16  19.730000  19.162542  4957700

# %%
data.tail()
# Out:
#             Date        Open        High  ...       Close   Adj Close    Volume
# 1254  2020-07-15  416.570007  417.320007  ...  409.089996  409.089996  10099600
# 1255  2020-07-16  400.600006  408.269989  ...  405.390015  405.390015   8624100
# 1256  2020-07-17  409.019989  409.940002  ...  408.059998  408.059998   6657100
# 1257  2020-07-20  410.970001  421.250000  ...  420.429993  420.429993   7121300
# 1258  2020-07-21  420.519989  422.399994  ...  413.140015  413.140015   6925900
#
# [5 rows x 7 columns]

# %%
# Split Training data
data_training = data[data['Date']<'2019-01-01'].copy()
data_training
# Out:
#            Date        Open        High  ...       Close   Adj Close    Volume
# 0    2015-07-22   19.650000   19.650000  ...   19.410000   18.851749   8911800
# 1    2015-07-23   19.450001   19.940001  ...   19.650000   19.084845   4247900
# 2    2015-07-24   19.790001   19.809999  ...   19.420000   18.861464   4721100
# 3    2015-07-27   19.250000   19.530001  ...   19.309999   18.754622   4810500
# 4    2015-07-28   19.360001   19.860001  ...   19.730000   19.162542   4957700
# ..          ...         ...         ...  ...         ...         ...       ...
# 863  2018-12-24  126.489998  129.979996  ...  127.080002  126.452255  11596000
# 864  2018-12-26  128.940002  133.139999  ...  133.100006  132.442535  17377500
# 865  2018-12-27  130.990005  132.380005  ...  131.169998  130.522049  15926100
# 866  2018-12-28  132.000000  137.389999  ...  133.649994  132.989807  15718200
# 867  2018-12-31  135.399994  136.710007  ...  133.500000  132.840530  11628500
#
# [868 rows x 7 columns]

# %%
# Split Testing data
data_test = data[data['Date']>='2019-01-01'].copy()
data_test
# Out:
#             Date        Open        High  ...       Close   Adj Close    Volume
# 868   2019-01-02  130.639999  138.479996  ...  136.220001  135.547104  12718800
# 869   2019-01-03  133.789993  135.160004  ...  127.989998  127.357750  17638800
# 870   2019-01-04  130.940002  137.729996  ...  136.190002  135.517258  14640500
# 871   2019-01-07  138.500000  144.889999  ...  143.399994  142.691620  17729000
# 872   2019-01-08  146.690002  146.779999  ...  139.830002  139.139282  19650400
# ...          ...         ...         ...  ...         ...         ...       ...
# 1254  2020-07-15  416.570007  417.320007  ...  409.089996  409.089996  10099600
# 1255  2020-07-16  400.600006  408.269989  ...  405.390015  405.390015   8624100
# 1256  2020-07-17  409.019989  409.940002  ...  408.059998  408.059998   6657100
# 1257  2020-07-20  410.970001  421.250000  ...  420.429993  420.429993   7121300
# 1258  2020-07-21  420.519989  422.399994  ...  413.140015  413.140015   6925900
#
# [391 rows x 7 columns]

# %%
training_data = data_training.drop(['Date', 'Adj Close'], axis = 1)
training_data.head()
# Out:
#         Open       High    Low      Close   Volume
# 0  19.650000  19.650000  19.17  19.410000  8911800
# 1  19.450001  19.940001  19.41  19.650000  4247900
# 2  19.790001  19.809999  19.34  19.420000  4721100
# 3  19.250000  19.530001  19.09  19.309999  4810500
# 4  19.360001  19.860001  19.16  19.730000  4957700

# %%
scaler = MinMaxScaler()
training_data = scaler.fit_transform(training_data)
training_data
# Out:
# array([[1.48109745e-03, 4.39186751e-04, 3.00198896e-04, 3.70305518e-04,
#         8.35120643e-02],
#        [7.40552430e-04, 1.50056724e-03, 1.20079559e-03, 1.25902987e-03,
#         3.22671736e-02],
#        [1.99948527e-03, 1.02477031e-03, 9.38121551e-04, 4.07335700e-04,
#         3.74664879e-02],
#        ...,
#        [4.13744593e-01, 4.13021997e-01, 3.98101261e-01, 4.14219607e-01,
#         1.60582121e-01],
#        [4.17484345e-01, 4.31358175e-01, 4.17351508e-01, 4.23403077e-01,
#         1.58297807e-01],
#        [4.30073651e-01, 4.28869458e-01, 4.24668845e-01, 4.22847646e-01,
#         1.13361974e-01]])

# %%
X_train = []
y_train = []

# %%
training_data.shape[0]
# Out:
# 868

# %%
for i in range(60, training_data.shape[0]):
  X_train.append(training_data[i-60:i])
  y_train.append(training_data[i, 0])

# %%
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
X_train.shape, y_train.shape
# Out:
# ((808, 60, 5), (808,))

# %%
X_old_shape = X_train.shape
X_train = X_train.reshape(X_old_shape[0], \
                          X_old_shape[1]*X_old_shape[2]) 
X_train.shape
# Out:
# (808, 300)

# %% [markdown]
# # **Building LSTM**

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout

# %%
regressor_ann = Sequential()
 
regressor_ann.add(Input(shape = (300,)))
regressor_ann.add(Dense(units = 512, activation = 'relu'))
regressor_ann.add(Dropout(0.2))
 
regressor_ann.add(Dense(units = 128, activation = 'relu'))
regressor_ann.add(Dropout(0.3))
 
regressor_ann.add(Dense(units = 64, activation = 'relu'))
regressor_ann.add(Dropout(0.4))
 
regressor_ann.add(Dense(units = 16, activation = 'relu'))
regressor_ann.add(Dropout(0.5))
 
regressor_ann.add(Dense(units = 1))
# Out:
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.

# %%
regressor_ann.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 512)               154112
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 128)               65664
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 16)                1040
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 229,089
# Trainable params: 229,089
# Non-trainable params: 0
# _________________________________________________________________

# %%
regressor_ann.compile(optimizer='adam', loss = 'mean_squared_error')

# %%
regressor_ann.fit(X_train, y_train, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 26/26 [==============================] - 1s 5ms/step - loss: 0.3118
# Epoch 2/10
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1209
# Epoch 3/10
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0988
# Epoch 4/10
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0915
# Epoch 5/10
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0794
# Epoch 6/10
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0673
# Epoch 7/10
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0629
# Epoch 8/10
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0607
# Epoch 9/10
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0531
# Epoch 10/10
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0550

# %%
## Now we will test and predict stock price

## Prepare test dataset
data_test.head()
# Out:
#            Date        Open        High  ...       Close   Adj Close    Volume
# 868  2019-01-02  130.639999  138.479996  ...  136.220001  135.547104  12718800
# 869  2019-01-03  133.789993  135.160004  ...  127.989998  127.357750  17638800
# 870  2019-01-04  130.940002  137.729996  ...  136.190002  135.517258  14640500
# 871  2019-01-07  138.500000  144.889999  ...  143.399994  142.691620  17729000
# 872  2019-01-08  146.690002  146.779999  ...  139.830002  139.139282  19650400
#
# [5 rows x 7 columns]

# %%
data_training.tail(60)
# Out:
#            Date        Open        High  ...       Close   Adj Close    Volume
# 808  2018-10-04  285.269989  286.250000  ...  279.290009  277.632599   9780500
# 809  2018-10-05  278.290009  280.799988  ...  269.859985  268.258514  10665900
# 810  2018-10-08  266.500000  271.160004  ...  265.769989  264.192780  10215300
# 811  2018-10-09  264.940002  268.760010  ...  265.540009  263.964203   6837500
# 812  2018-10-10  261.260010  263.109985  ...  245.690002  244.231964  17123500
# 813  2018-10-11  242.169998  247.559998  ...  235.130005  233.734634  18135900
# 814  2018-10-12  245.509995  249.539993  ...  246.539993  245.076920  15205900
# 815  2018-10-15  246.000000  246.000000  ...  235.380005  233.983154  11244000
# 816  2018-10-16  239.929993  246.279999  ...  245.830002  244.371155  10217800
# 817  2018-10-17  248.339996  249.880005  ...  243.059998  241.617569   8241700
# 818  2018-10-18  245.860001  247.410004  ...  239.529999  238.108536  13100500
# 819  2018-10-19  241.759995  242.550003  ...  229.169998  227.810013  15340200
# 820  2018-10-22  231.279999  235.320007  ...  231.220001  229.847855   9221100
# 821  2018-10-23  220.429993  224.190002  ...  221.059998  219.748138  15660900
# 822  2018-10-24  219.509995  221.389999  ...  199.410004  198.226608  22107200
# 823  2018-10-25  195.470001  209.750000  ...  207.839996  206.606567  23793000
# 824  2018-10-26  198.309998  204.839996  ...  198.289993  197.113251  16619600
# 825  2018-10-29  203.990005  204.130005  ...  185.619995  184.518448  18950400
# 826  2018-10-30  186.550003  203.399994  ...  203.000000  201.795303  20179800
# 827  2018-10-31  209.649994  212.589996  ...  210.830002  209.578857  18644300
# 828  2018-11-01  212.300003  218.490005  ...  218.110001  216.815628  14163200
# 829  2018-11-02  217.729996  222.000000  ...  214.919998  213.644562  11324000
# 830  2018-11-05  214.389999  215.330002  ...  211.770004  210.513275   9483300
# 831  2018-11-06  211.449997  214.850006  ...  211.059998  209.807495   7475300
# 832  2018-11-07  213.750000  217.410004  ...  213.789993  212.521271  12095300
# 833  2018-11-08  211.399994  211.429993  ...  205.990005  204.767578  12783800
# 834  2018-11-09  202.399994  209.320007  ...  205.669998  204.449463  10331000
# 835  2018-11-12  201.979996  202.869995  ...  189.539993  188.415192  15427900
# 836  2018-11-13  193.490005  204.210007  ...  199.309998  198.127213  16117800
# 837  2018-11-14  206.300003  206.880005  ...  197.190002  196.019791  13164500
# 838  2018-11-15  196.949997  205.300003  ...  202.389999  201.188919  21017700
# 839  2018-11-16  163.320007  170.660004  ...  164.429993  163.454178  49088000
# 840  2018-11-19  161.789993  161.820007  ...  144.699997  143.841278  42445500
# 841  2018-11-20  134.059998  154.259995  ...  149.080002  148.195297  42300800
# 842  2018-11-21  154.619995  155.300003  ...  144.710007  143.851242  25637400
# 843  2018-11-23  143.309998  149.589996  ...  145.000000  144.139511  10299200
# 844  2018-11-26  149.889999  153.470001  ...  153.050003  152.141739  20370800
# 845  2018-11-27  152.000000  157.009995  ...  153.729996  152.817703  18451500
# 846  2018-11-28  158.479996  160.279999  ...  160.070007  159.120102  20113100
# 847  2018-11-29  160.000000  161.500000  ...  157.360001  156.582672  13729300
# 848  2018-11-30  157.750000  163.860001  ...  163.429993  162.622681  18239100
# 849  2018-12-03  172.600006  174.679993  ...  170.039993  169.200043  22270100
# 850  2018-12-04  168.240005  168.440002  ...  157.110001  156.333908  20302800
# 851  2018-12-06  151.440002  158.490005  ...  158.289993  157.508072  17307700
# 852  2018-12-07  158.460007  158.869995  ...  147.610001  146.880844  17041900
# 853  2018-12-10  145.800003  152.860001  ...  151.860001  151.109848  15736800
# 854  2018-12-11  155.559998  155.889999  ...  148.190002  147.457977  16797800
# 855  2018-12-12  148.419998  152.779999  ...  148.899994  148.164474  16353400
# 856  2018-12-13  150.789993  153.380005  ...  148.889999  148.154495  11784600
# 857  2018-12-14  147.210007  150.589996  ...  146.449997  145.726563  11795500
# 858  2018-12-17  145.240005  148.149994  ...  143.580002  142.870728  16571700
# 859  2018-12-18  145.350006  150.330002  ...  146.940002  146.214142  14109300
# 860  2018-12-19  145.580002  147.740005  ...  138.509995  137.825806  18634100
# 861  2018-12-20  138.169998  141.800003  ...  135.100006  134.432632  18739700
# 862  2018-12-21  136.169998  137.500000  ...  129.570007  128.929977  21593500
# 863  2018-12-24  126.489998  129.979996  ...  127.080002  126.452255  11596000
# 864  2018-12-26  128.940002  133.139999  ...  133.100006  132.442535  17377500
# 865  2018-12-27  130.990005  132.380005  ...  131.169998  130.522049  15926100
# 866  2018-12-28  132.000000  137.389999  ...  133.649994  132.989807  15718200
# 867  2018-12-31  135.399994  136.710007  ...  133.500000  132.840530  11628500
#
# [60 rows x 7 columns]

# %%
past_60_days = data_training.tail(60)

# %%
df = past_60_days.append(data_test, ignore_index = True)
df = df.drop(['Date', 'Adj Close'], axis = 1)
df.head()
# Out:
#          Open        High         Low       Close    Volume
# 0  285.269989  286.250000  276.179993  279.290009   9780500
# 1  278.290009  280.799988  267.540009  269.859985  10665900
# 2  266.500000  271.160004  260.079987  265.769989  10215300
# 3  264.940002  268.760010  262.799988  265.540009   6837500
# 4  261.260010  263.109985  245.600006  245.690002  17123500

# %%
inputs = scaler.transform(df)
inputs
# Out:
# array([[0.98500382, 0.97617388, 0.96472665, 0.9627107 , 0.09305696],
#        [0.95915875, 0.95622728, 0.93230523, 0.92779115, 0.10278535],
#        [0.91550336, 0.9209457 , 0.9043116 , 0.91264582, 0.09783435],
#        ...,
#        [1.44321835, 1.42886941, 1.44253078, 1.4395483 , 0.05873841],
#        [1.45043874, 1.4702631 , 1.45288757, 1.48535462, 0.06383883],
#        [1.4857999 , 1.47447198, 1.47240054, 1.4583597 , 0.06169186]])

# %%
X_test = []
y_test = []

for i in range(60, inputs.shape[0]):
  X_test.append(inputs[i-60:i])
  y_test.append(inputs[i, 0])

# %%
X_test, y_test = np.array(X_test), np.array(y_test)
 
X_old_shape = X_test.shape
X_test = X_test.reshape(X_old_shape[0], \
                        X_old_shape[1] * X_old_shape[2])
 
X_test.shape, y_test.shape
# Out:
# ((391, 300), (391,))

# %%
y_pred = regressor_ann.predict(X_test)

# %%
scaler.scale_
# Out:
# array([3.70274364e-03, 3.65992009e-03, 3.75248621e-03, 3.70301815e-03,
#        1.09875621e-08])

# %%
scale = 1/3.70274364e-03
scale
# Out:
# 270.0700067909643

# %%
y_pred = y_pred*scale
y_test = y_test*scale

# %%
y_pred
# Out:
# array([[112.719376],
#        [112.465744],
#        [112.049904],
#        [111.09839 ],
#        [108.3065  ],
#        [108.134514],
#        [107.56325 ],
#        [107.39969 ],
#        [105.26558 ],
#        [105.582855],
#        [104.81111 ],
#        [104.904724],
#        [103.781906],
#        [102.80867 ],
#        [101.559975],
#        [101.37113 ],
#        [101.43943 ],
#        [100.672775],
#        [100.55149 ],
#        [101.14084 ],
#        [ 99.67398 ],
#        [ 99.42499 ],
#        [101.01379 ],
#        [100.25624 ],
#        [100.42657 ],
#        [100.69387 ],
#        [101.0402  ],
#        [ 99.7781  ],
#        [ 98.877525],
#        [ 98.98626 ],
#        [ 99.17654 ],
#        [ 95.61532 ],
#        [ 96.76469 ],
#        [ 97.49977 ],
#        [ 98.26516 ],
#        [ 98.68969 ],
#        [ 99.81691 ],
#        [100.77794 ],
#        [ 99.75335 ],
#        [100.794945],
#        [ 99.58059 ],
#        [ 99.29533 ],
#        [101.21294 ],
#        [101.48705 ],
#        [100.78121 ],
#        [100.79219 ],
#        [102.19295 ],
#        [100.87101 ],
#        [101.02818 ],
#        [101.767815],
#        [101.39531 ],
#        [100.6144  ],
#        [100.76553 ],
#        [102.65353 ],
#        [ 98.42248 ],
#        [102.02583 ],
#        [102.42787 ],
#        [103.5807  ],
#        [102.11175 ],
#        [103.026726],
#        [102.99211 ],
#        [105.08892 ],
#        [105.63452 ],
#        [105.75838 ],
#        [105.49154 ],
#        [107.10327 ],
#        [107.26271 ],
#        [106.821846],
#        [106.477425],
#        [108.196014],
#        [110.229805],
#        [110.5222  ],
#        [110.338905],
#        [111.036835],
#        [112.02805 ],
#        [111.24375 ],
#        [113.02999 ],
#        [113.08141 ],
#        [113.31161 ],
#        [114.56817 ],
#        [113.52732 ],
#        [114.74268 ],
#        [114.89414 ],
#        [114.36781 ],
#        [115.77152 ],
#        [115.42892 ],
#        [115.496864],
#        [114.93439 ],
#        [116.88469 ],
#        [114.486046],
#        [115.96485 ],
#        [114.45575 ],
#        [115.34176 ],
#        [114.763466],
#        [113.82669 ],
#        [113.75918 ],
#        [113.31387 ],
#        [113.19871 ],
#        [113.13747 ],
#        [113.290985],
#        [112.37146 ],
#        [112.60391 ],
#        [110.53158 ],
#        [111.375206],
#        [110.34343 ],
#        [110.592545],
#        [109.84744 ],
#        [110.315125],
#        [109.81375 ],
#        [109.52221 ],
#        [110.05944 ],
#        [109.96181 ],
#        [108.965706],
#        [109.32997 ],
#        [109.21511 ],
#        [108.624596],
#        [108.127945],
#        [108.35228 ],
#        [108.78776 ],
#        [108.6243  ],
#        [108.32374 ],
#        [107.93803 ],
#        [107.93132 ],
#        [107.85859 ],
#        [107.448524],
#        [107.37244 ],
#        [107.55912 ],
#        [107.581955],
#        [107.17649 ],
#        [106.945786],
#        [107.85688 ],
#        [106.87286 ],
#        [107.34674 ],
#        [107.88123 ],
#        [107.84546 ],
#        [107.295105],
#        [108.34081 ],
#        [107.87046 ],
#        [107.75088 ],
#        [107.56936 ],
#        [108.3684  ],
#        [108.38864 ],
#        [108.112976],
#        [109.22848 ],
#        [109.14332 ],
#        [109.36103 ],
#        [110.06371 ],
#        [109.81536 ],
#        [108.86557 ],
#        [108.3348  ],
#        [108.56097 ],
#        [108.85525 ],
#        [108.36859 ],
#        [108.88387 ],
#        [108.2319  ],
#        [108.97988 ],
#        [108.25213 ],
#        [108.66846 ],
#        [107.5649  ],
#        [107.867294],
#        [108.3721  ],
#        [108.183525],
#        [109.1293  ],
#        [109.304245],
#        [109.695755],
#        [109.76148 ],
#        [109.9225  ],
#        [110.182365],
#        [109.96401 ],
#        [109.75731 ],
#        [109.80262 ],
#        [109.732414],
#        [110.316666],
#        [110.14124 ],
#        [110.71476 ],
#        [111.00359 ],
#        [110.78763 ],
#        [111.68805 ],
#        [111.80529 ],
#        [113.10641 ],
#        [113.36215 ],
#        [113.31378 ],
#        [113.656296],
#        [114.016945],
#        [113.4775  ],
#        [113.51956 ],
#        [113.90225 ],
#        [114.03705 ],
#        [114.159035],
#        [113.6351  ],
#        [114.21032 ],
#        [113.56982 ],
#        [114.67054 ],
#        [114.03207 ],
#        [113.75039 ],
#        [114.91784 ],
#        [115.286026],
#        [115.44107 ],
#        [116.419685],
#        [116.41625 ],
#        [116.86295 ],
#        [116.759514],
#        [117.65365 ],
#        [117.65099 ],
#        [117.69502 ],
#        [117.776955],
#        [117.509766],
#        [117.10244 ],
#        [118.841446],
#        [117.78756 ],
#        [119.54867 ],
#        [120.04046 ],
#        [120.100716],
#        [120.19993 ],
#        [121.28422 ],
#        [121.436554],
#        [122.32393 ],
#        [122.12527 ],
#        [122.89785 ],
#        [123.95867 ],
#        [124.614174],
#        [124.38886 ],
#        [123.51758 ],
#        [124.2775  ],
#        [124.771   ],
#        [124.725266],
#        [125.583305],
#        [126.10032 ],
#        [127.43244 ],
#        [127.04673 ],
#        [128.00076 ],
#        [128.13872 ],
#        [128.5026  ],
#        [128.68626 ],
#        [129.49846 ],
#        [128.42044 ],
#        [129.67949 ],
#        [129.81186 ],
#        [130.2724  ],
#        [129.73747 ],
#        [130.0147  ],
#        [130.31451 ],
#        [130.60356 ],
#        [131.56319 ],
#        [131.77115 ],
#        [131.60796 ],
#        [132.54518 ],
#        [132.76546 ],
#        [133.5392  ],
#        [135.06892 ],
#        [135.0173  ],
#        [135.1946  ],
#        [136.19278 ],
#        [136.74019 ],
#        [136.29848 ],
#        [136.41481 ],
#        [136.8516  ],
#        [137.66757 ],
#        [137.15863 ],
#        [137.97365 ],
#        [138.6398  ],
#        [139.24252 ],
#        [139.43695 ],
#        [139.99107 ],
#        [140.16052 ],
#        [141.22498 ],
#        [141.84819 ],
#        [143.00864 ],
#        [142.8111  ],
#        [143.10085 ],
#        [143.27551 ],
#        [143.86475 ],
#        [143.77019 ],
#        [143.83662 ],
#        [144.57387 ],
#        [144.80295 ],
#        [144.56459 ],
#        [145.49048 ],
#        [145.80461 ],
#        [145.18875 ],
#        [146.09932 ],
#        [146.6707  ],
#        [146.32178 ],
#        [147.60405 ],
#        [149.11069 ],
#        [149.99966 ],
#        [150.9185  ],
#        [151.4967  ],
#        [152.42207 ],
#        [152.2005  ],
#        [152.31323 ],
#        [152.21388 ],
#        [151.62148 ],
#        [153.13884 ],
#        [153.83241 ],
#        [153.97339 ],
#        [154.51338 ],
#        [155.72998 ],
#        [155.43204 ],
#        [155.08728 ],
#        [156.06935 ],
#        [154.58719 ],
#        [154.34102 ],
#        [154.41837 ],
#        [154.16615 ],
#        [153.27505 ],
#        [153.84044 ],
#        [154.04892 ],
#        [153.13205 ],
#        [151.44626 ],
#        [152.59259 ],
#        [151.98347 ],
#        [151.90053 ],
#        [152.19199 ],
#        [152.53297 ],
#        [152.23764 ],
#        [151.18085 ],
#        [151.79097 ],
#        [151.134   ],
#        [150.60922 ],
#        [153.01636 ],
#        [152.00105 ],
#        [152.12973 ],
#        [151.48741 ],
#        [151.6408  ],
#        [151.3273  ],
#        [151.5216  ],
#        [151.60994 ],
#        [151.39081 ],
#        [152.15456 ],
#        [153.85132 ],
#        [152.7228  ],
#        [154.47192 ],
#        [154.88048 ],
#        [156.39749 ],
#        [156.77603 ],
#        [156.51373 ],
#        [157.90231 ],
#        [158.5356  ],
#        [160.77962 ],
#        [158.8723  ],
#        [160.74472 ],
#        [161.41988 ],
#        [159.76123 ],
#        [162.7631  ],
#        [161.52571 ],
#        [162.83675 ],
#        [162.593   ],
#        [163.65839 ],
#        [164.84622 ],
#        [166.12589 ],
#        [168.80013 ],
#        [168.56516 ],
#        [170.9609  ],
#        [171.95648 ],
#        [170.92508 ],
#        [170.85448 ],
#        [172.54167 ],
#        [174.85008 ],
#        [176.29755 ],
#        [176.2731  ],
#        [176.59978 ],
#        [178.71854 ],
#        [179.39915 ],
#        [179.71657 ],
#        [180.36453 ],
#        [181.59758 ],
#        [184.34062 ],
#        [185.05656 ],
#        [186.65416 ],
#        [188.61732 ],
#        [189.28119 ],
#        [189.9631  ],
#        [190.37851 ],
#        [191.38118 ],
#        [193.02644 ],
#        [193.23512 ],
#        [193.94221 ],
#        [195.28175 ],
#        [195.64682 ],
#        [195.60086 ],
#        [197.62889 ],
#        [198.05411 ],
#        [199.47212 ],
#        [200.83722 ],
#        [200.79657 ],
#        [201.30476 ],
#        [202.96906 ],
#        [202.90135 ],
#        [203.84946 ],
#        [206.07977 ]], dtype=float32)

# %% [markdown]
# # **Visualization**

# %%
plt.figure(figsize=(14,5))
plt.plot(y_test, color = 'black', label = "Real NVDA Stock Price")
plt.plot(y_pred, color = 'grey', label = 'Predicted NVDA Stock Price')
plt.title('NVDA Stock Price Prediction')
plt.xlabel('time')
plt.ylabel('NVDA Stock Price')
plt.legend()
plt.show()
