# %% [markdown]
# # Exercise 4.02

# %%
import tensorflow as tf
import pandas as pd

# %%
df = pd.read_csv('../Datasets/Bias_correction_ucl.csv')

# %%
df.drop('Date', inplace=True, axis=1)
df.dropna(inplace=True)

# %%
target = df[['Next_Tmax', 'Next_Tmin']]
features = df.drop(['Next_Tmax', 'Next_Tmin'], axis=1)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
feature_array = scaler.fit_transform(features)
features = pd.DataFrame(feature_array, columns=features.columns)

# %%
model = tf.keras.Sequential()

# %%
model.add(tf.keras.layers.InputLayer(input_shape=(features.shape[1],), name='Input_layer'))
model.add(tf.keras.layers.Dense(2, name='Output_layer'))

# %%
model.compile(tf.optimizers.RMSprop(0.001), loss='mse')

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir="./logs")

# %%
model.fit(x=features.to_numpy(), y=target.to_numpy(), epochs=50, callbacks=[tensorboard_callback])
# Out:
# Train on 7588 samples
# Epoch 1/50
# 7588/7588 [==============================] - 1s 95us/sample - loss: 672.4736
# Epoch 2/50
# 7588/7588 [==============================] - 0s 31us/sample - loss: 567.2860
# Epoch 3/50
# 7588/7588 [==============================] - 0s 32us/sample - loss: 471.6400
# Epoch 4/50
# 7588/7588 [==============================] - 0s 39us/sample - loss: 385.5685
# Epoch 5/50
# 7588/7588 [==============================] - 0s 32us/sample - loss: 309.2351
# Epoch 6/50
# 7588/7588 [==============================] - 0s 31us/sample - loss: 242.2700
# Epoch 7/50
# 7588/7588 [==============================] - 0s 32us/sample - loss: 184.9987
# Epoch 8/50
# 7588/7588 [==============================] - 0s 36us/sample - loss: 137.3421
# Epoch 9/50
# 7588/7588 [==============================] - 0s 31us/sample - loss: 99.2319
# Epoch 10/50
# 7588/7588 [==============================] - 0s 31us/sample - loss: 70.5667
# Epoch 11/50
# 7588/7588 [==============================] - 0s 32us/sample - loss: 50.4159
# Epoch 12/50
# 7588/7588 [==============================] - 0s 48us/sample - loss: 36.6329
# Epoch 13/50
# 7588/7588 [==============================] - 0s 39us/sample - loss: 27.7067
# Epoch 14/50
# 7588/7588 [==============================] - 0s 31us/sample - loss: 22.5653
# Epoch 15/50
# 7588/7588 [==============================] - 0s 34us/sample - loss: 19.5886
# Epoch 16/50
# 7588/7588 [==============================] - 0s 31us/sample - loss: 17.5507
# Epoch 17/50
# 7588/7588 [==============================] - 0s 33us/sample - loss: 15.8333
# Epoch 18/50
# 7588/7588 [==============================] - 0s 30us/sample - loss: 14.3125
# Epoch 19/50
# 7588/7588 [==============================] - 0s 42us/sample - loss: 12.9495
# Epoch 20/50
# 7588/7588 [==============================] - 0s 32us/sample - loss: 11.7407
# Epoch 21/50
# 7588/7588 [==============================] - 0s 33us/sample - loss: 10.6765
# Epoch 22/50
# 7588/7588 [==============================] - 0s 32us/sample - loss: 9.7145
# Epoch 23/50
# 7588/7588 [==============================] - 0s 37us/sample - loss: 8.8605
# Epoch 24/50
# 7588/7588 [==============================] - 0s 35us/sample - loss: 8.1049
# Epoch 25/50
# 7588/7588 [==============================] - 0s 35us/sample - loss: 7.4634
# Epoch 26/50
# 7588/7588 [==============================] - 0s 32us/sample - loss: 6.9007
# Epoch 27/50
# 7588/7588 [==============================] - 0s 37us/sample - loss: 6.4242
# Epoch 28/50
# 7588/7588 [==============================] - 0s 32us/sample - loss: 6.0293
# Epoch 29/50
# 7588/7588 [==============================] - 0s 31us/sample - loss: 5.6866
# Epoch 30/50
# 7588/7588 [==============================] - 0s 30us/sample - loss: 5.4027
# Epoch 31/50
# 7588/7588 [==============================] - 0s 44us/sample - loss: 5.1591
# Epoch 32/50
# 7588/7588 [==============================] - 0s 33us/sample - loss: 4.9601
# Epoch 33/50
# 7588/7588 [==============================] - 0s 32us/sample - loss: 4.7950
# Epoch 34/50
# 7588/7588 [==============================] - 0s 31us/sample - loss: 4.6594
# Epoch 35/50
# 7588/7588 [==============================] - 0s 35us/sample - loss: 4.5436
# Epoch 36/50
# 7588/7588 [==============================] - 0s 32us/sample - loss: 4.4348
# Epoch 37/50
# 7588/7588 [==============================] - 0s 31us/sample - loss: 4.3430
# Epoch 38/50
# 7588/7588 [==============================] - 0s 30us/sample - loss: 4.2584
# Epoch 39/50
# 7588/7588 [==============================] - 0s 36us/sample - loss: 4.1813
# Epoch 40/50
# 7588/7588 [==============================] - 0s 31us/sample - loss: 4.1065
# Epoch 41/50
# 7588/7588 [==============================] - 0s 30us/sample - loss: 4.0407
# Epoch 42/50
# 7588/7588 [==============================] - 0s 31us/sample - loss: 3.9787
# Epoch 43/50
# 7588/7588 [==============================] - 0s 32us/sample - loss: 3.9191
# Epoch 44/50
# 7588/7588 [==============================] - 0s 32us/sample - loss: 3.8635
# Epoch 45/50
# 7588/7588 [==============================] - 0s 31us/sample - loss: 3.8094
# Epoch 46/50
# 7588/7588 [==============================] - 0s 32us/sample - loss: 3.7578
# Epoch 47/50
# 7588/7588 [==============================] - 0s 35us/sample - loss: 3.7084
# Epoch 48/50
# 7588/7588 [==============================] - 0s 35us/sample - loss: 3.6604
# Epoch 49/50
# 7588/7588 [==============================] - 0s 32us/sample - loss: 3.6153
# Epoch 50/50
# 7588/7588 [==============================] - 0s 33us/sample - loss: 3.5710

# %%
loss = model.evaluate(features.to_numpy(), target.to_numpy())
print('loss:', loss)
# Out:
# 7588/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# loss: 3.5468221449764012
