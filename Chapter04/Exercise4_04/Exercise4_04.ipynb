# %% [markdown]
# # Exercise 4.04

# %%
import tensorflow as tf
import pandas as pd

# %%
df = pd.read_csv('../Datasets/qsar_androgen_receptor.csv', sep=';')

# %%
df.dropna(inplace=True)

# %%
df['positive'].value_counts()
# Out:
# negative    1488
# positive     198
# Name: positive, dtype: int64

# %%
target = df['positive'].apply(lambda x: 1 if x=='positive' else 0)
features = df.drop('positive', axis=1)

# %%
model = tf.keras.Sequential()

# %%
model.add(tf.keras.layers.InputLayer(input_shape=(features.shape[1],), name='Input_layer'))
model.add(tf.keras.layers.Dense(1, name='Output_layer', activation='sigmoid'))

# %%
model.compile(tf.optimizers.RMSprop(0.0001), loss='binary_crossentropy', metrics=['accuracy'])

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir="./logs")

# %%
model.fit(x=features.to_numpy(), y=target.to_numpy(),
          epochs=50, callbacks=[tensorboard_callback], validation_split=0.2)
# Out:
# Train on 1348 samples, validate on 338 samples
# Epoch 1/50
# 1348/1348 [==============================] - 1s 502us/sample - loss: 0.6916 - accuracy: 0.5141 - val_loss: 0.5795 - val_accuracy: 0.8018
# Epoch 2/50
# 1348/1348 [==============================] - 0s 66us/sample - loss: 0.6259 - accuracy: 0.7136 - val_loss: 0.4913 - val_accuracy: 0.8876
# Epoch 3/50
# 1348/1348 [==============================] - 0s 57us/sample - loss: 0.5800 - accuracy: 0.8027 - val_loss: 0.4328 - val_accuracy: 0.9201
# Epoch 4/50
# 1348/1348 [==============================] - 0s 65us/sample - loss: 0.5467 - accuracy: 0.8472 - val_loss: 0.3916 - val_accuracy: 0.9260
# Epoch 5/50
# 1348/1348 [==============================] - 0s 64us/sample - loss: 0.5219 - accuracy: 0.8628 - val_loss: 0.3642 - val_accuracy: 0.9260
# Epoch 6/50
# 1348/1348 [==============================] - 0s 67us/sample - loss: 0.5031 - accuracy: 0.8680 - val_loss: 0.3469 - val_accuracy: 0.9260
# Epoch 7/50
# 1348/1348 [==============================] - 0s 58us/sample - loss: 0.4885 - accuracy: 0.8687 - val_loss: 0.3337 - val_accuracy: 0.9260
# Epoch 8/50
# 1348/1348 [==============================] - 0s 59us/sample - loss: 0.4761 - accuracy: 0.8709 - val_loss: 0.3232 - val_accuracy: 0.9260
# Epoch 9/50
# 1348/1348 [==============================] - 0s 62us/sample - loss: 0.4655 - accuracy: 0.8717 - val_loss: 0.3163 - val_accuracy: 0.9260
# Epoch 10/50
# 1348/1348 [==============================] - 0s 63us/sample - loss: 0.4562 - accuracy: 0.8717 - val_loss: 0.3100 - val_accuracy: 0.9260
# Epoch 11/50
# 1348/1348 [==============================] - 0s 55us/sample - loss: 0.4473 - accuracy: 0.8717 - val_loss: 0.3054 - val_accuracy: 0.9260
# Epoch 12/50
# 1348/1348 [==============================] - 0s 62us/sample - loss: 0.4384 - accuracy: 0.8717 - val_loss: 0.2998 - val_accuracy: 0.9260
# Epoch 13/50
# 1348/1348 [==============================] - 0s 61us/sample - loss: 0.4302 - accuracy: 0.8717 - val_loss: 0.2967 - val_accuracy: 0.9260
# Epoch 14/50
# 1348/1348 [==============================] - 0s 66us/sample - loss: 0.4226 - accuracy: 0.8717 - val_loss: 0.2930 - val_accuracy: 0.9260
# Epoch 15/50
# 1348/1348 [==============================] - 0s 62us/sample - loss: 0.4153 - accuracy: 0.8717 - val_loss: 0.2903 - val_accuracy: 0.9260
# Epoch 16/50
# 1348/1348 [==============================] - 0s 65us/sample - loss: 0.4080 - accuracy: 0.8717 - val_loss: 0.2894 - val_accuracy: 0.9260
# Epoch 17/50
# 1348/1348 [==============================] - 0s 57us/sample - loss: 0.4019 - accuracy: 0.8717 - val_loss: 0.2866 - val_accuracy: 0.9260
# Epoch 18/50
# 1348/1348 [==============================] - 0s 76us/sample - loss: 0.3957 - accuracy: 0.8717 - val_loss: 0.2846 - val_accuracy: 0.9290
# Epoch 19/50
# 1348/1348 [==============================] - 0s 63us/sample - loss: 0.3894 - accuracy: 0.8731 - val_loss: 0.2831 - val_accuracy: 0.9290
# Epoch 20/50
# 1348/1348 [==============================] - 0s 63us/sample - loss: 0.3833 - accuracy: 0.8731 - val_loss: 0.2831 - val_accuracy: 0.9320
# Epoch 21/50
# 1348/1348 [==============================] - 0s 56us/sample - loss: 0.3775 - accuracy: 0.8761 - val_loss: 0.2817 - val_accuracy: 0.9320
# Epoch 22/50
# 1348/1348 [==============================] - 0s 60us/sample - loss: 0.3721 - accuracy: 0.8769 - val_loss: 0.2815 - val_accuracy: 0.9320
# Epoch 23/50
# 1348/1348 [==============================] - 0s 59us/sample - loss: 0.3666 - accuracy: 0.8776 - val_loss: 0.2818 - val_accuracy: 0.9349
# Epoch 24/50
# 1348/1348 [==============================] - 0s 63us/sample - loss: 0.3614 - accuracy: 0.8791 - val_loss: 0.2822 - val_accuracy: 0.9349
# Epoch 25/50
# 1348/1348 [==============================] - 0s 67us/sample - loss: 0.3565 - accuracy: 0.8791 - val_loss: 0.2825 - val_accuracy: 0.9379
# Epoch 26/50
# 1348/1348 [==============================] - 0s 56us/sample - loss: 0.3518 - accuracy: 0.8783 - val_loss: 0.2823 - val_accuracy: 0.9408
# Epoch 27/50
# 1348/1348 [==============================] - 0s 60us/sample - loss: 0.3472 - accuracy: 0.8783 - val_loss: 0.2828 - val_accuracy: 0.9467
# Epoch 28/50
# 1348/1348 [==============================] - 0s 66us/sample - loss: 0.3426 - accuracy: 0.8798 - val_loss: 0.2818 - val_accuracy: 0.9467
# Epoch 29/50
# 1348/1348 [==============================] - 0s 57us/sample - loss: 0.3384 - accuracy: 0.8828 - val_loss: 0.2808 - val_accuracy: 0.9467
# Epoch 30/50
# 1348/1348 [==============================] - 0s 56us/sample - loss: 0.3342 - accuracy: 0.8835 - val_loss: 0.2815 - val_accuracy: 0.9497
# Epoch 31/50
# 1348/1348 [==============================] - 0s 52us/sample - loss: 0.3300 - accuracy: 0.8835 - val_loss: 0.2812 - val_accuracy: 0.9497
# Epoch 32/50
# 1348/1348 [==============================] - 0s 54us/sample - loss: 0.3262 - accuracy: 0.8858 - val_loss: 0.2807 - val_accuracy: 0.9556
# Epoch 33/50
# 1348/1348 [==============================] - 0s 53us/sample - loss: 0.3226 - accuracy: 0.8858 - val_loss: 0.2808 - val_accuracy: 0.9556
# Epoch 34/50
# 1348/1348 [==============================] - 0s 55us/sample - loss: 0.3190 - accuracy: 0.8865 - val_loss: 0.2818 - val_accuracy: 0.9586
# Epoch 35/50
# 1348/1348 [==============================] - 0s 58us/sample - loss: 0.3155 - accuracy: 0.8887 - val_loss: 0.2813 - val_accuracy: 0.9556
# Epoch 36/50
# 1348/1348 [==============================] - 0s 59us/sample - loss: 0.3120 - accuracy: 0.8895 - val_loss: 0.2822 - val_accuracy: 0.9527
# Epoch 37/50
# 1348/1348 [==============================] - 0s 52us/sample - loss: 0.3088 - accuracy: 0.8917 - val_loss: 0.2845 - val_accuracy: 0.9497
# Epoch 38/50
# 1348/1348 [==============================] - 0s 52us/sample - loss: 0.3058 - accuracy: 0.8947 - val_loss: 0.2837 - val_accuracy: 0.9467
# Epoch 39/50
# 1348/1348 [==============================] - 0s 55us/sample - loss: 0.3028 - accuracy: 0.8939 - val_loss: 0.2840 - val_accuracy: 0.9467
# Epoch 40/50
# 1348/1348 [==============================] - 0s 51us/sample - loss: 0.3001 - accuracy: 0.8969 - val_loss: 0.2850 - val_accuracy: 0.9438
# Epoch 41/50
# 1348/1348 [==============================] - 0s 60us/sample - loss: 0.2974 - accuracy: 0.8999 - val_loss: 0.2856 - val_accuracy: 0.9379
# Epoch 42/50
# 1348/1348 [==============================] - 0s 51us/sample - loss: 0.2947 - accuracy: 0.8999 - val_loss: 0.2880 - val_accuracy: 0.9349
# Epoch 43/50
# 1348/1348 [==============================] - 0s 56us/sample - loss: 0.2921 - accuracy: 0.9021 - val_loss: 0.2892 - val_accuracy: 0.9231
# Epoch 44/50
# 1348/1348 [==============================] - 0s 79us/sample - loss: 0.2895 - accuracy: 0.9043 - val_loss: 0.2901 - val_accuracy: 0.9231
# Epoch 45/50
# 1348/1348 [==============================] - 0s 70us/sample - loss: 0.2869 - accuracy: 0.9058 - val_loss: 0.2904 - val_accuracy: 0.9201
# Epoch 46/50
# 1348/1348 [==============================] - 0s 66us/sample - loss: 0.2845 - accuracy: 0.9080 - val_loss: 0.2901 - val_accuracy: 0.9201
# Epoch 47/50
# 1348/1348 [==============================] - 0s 52us/sample - loss: 0.2822 - accuracy: 0.9088 - val_loss: 0.2917 - val_accuracy: 0.9172
# Epoch 48/50
# 1348/1348 [==============================] - 0s 62us/sample - loss: 0.2800 - accuracy: 0.9095 - val_loss: 0.2920 - val_accuracy: 0.9172
# Epoch 49/50
# 1348/1348 [==============================] - 0s 61us/sample - loss: 0.2780 - accuracy: 0.9095 - val_loss: 0.2938 - val_accuracy: 0.9112
# Epoch 50/50
# 1348/1348 [==============================] - 0s 56us/sample - loss: 0.2759 - accuracy: 0.9110 - val_loss: 0.2935 - val_accuracy: 0.9112

# %%
loss,accuracy = model.evaluate(features.to_numpy(), target.to_numpy())
print(f'loss: {loss}, accuracy: {accuracy}')
# Out:
# 1686/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# loss: 0.2781583094794838, accuracy: 0.9110320210456848

# %%
model.variables
# Out:
# [<tf.Variable 'Output_layer/kernel:0' shape=(1024, 1) dtype=float32, numpy=
#  array([[-0.04666789],
#         [ 0.03833476],
#         [-0.02885724],
#         ...,
#         [ 0.064165  ],
#         [ 0.07677313],
#         [-0.05438004]], dtype=float32)>,
#  <tf.Variable 'Output_layer/bias:0' shape=(1,) dtype=float32, numpy=array([-0.15284424], dtype=float32)>]
