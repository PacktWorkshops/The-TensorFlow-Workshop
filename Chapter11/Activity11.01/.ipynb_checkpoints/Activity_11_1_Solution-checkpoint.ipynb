# %% [markdown]
# # **Activity 11.1 Generate Images with DCGAN**

# %%
try:
    from google.colab import drive
    drive.mount('/content/drive', force_remount=True)
    COLAB = True
    print("Note: using Google CoLab")
    # %tensorflow_version 2.x
except:
    print("Note: not using Google CoLab")
    COLAB = False
# Out:
# Mounted at /content/drive
# Note: using Google CoLab

# %% [markdown]
# ## **Import needed libraries**

# %%
import tensorflow as tf
from tensorflow.keras.layers import InputLayer, Reshape, Dropout, Dense 
from tensorflow.keras.layers import Flatten, BatchNormalization
from tensorflow.keras.layers import Activation, ZeroPadding2D
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.optimizers import Adam
import zipfile
import numpy as np
from PIL import Image
from tqdm import tqdm
import os 
import time
import matplotlib.pyplot as plt
from skimage.io import imread

# %%
def hms_string(sec_elapsed):
    h = int(sec_elapsed / (60 * 60))
    m = int((sec_elapsed % (60 * 60)) / 60)
    s = sec_elapsed % 60
    return "{}:{:>02}:{:>05.2f}".format(h, m, s)

# %% [markdown]
# ## **Resolution, channels, preview rows and columns, SEED, DATA PATH, EPOCH, BATCH SIZE, BUFFER SIZE**

# %%
gen_res = 3
gen_square = 32 * gen_res
img_chan = 3
img_rows = 5
img_cols = 5
img_margin = 16
seed_vector = 200
data_path = '/content/drive/MyDrive/Datasets/banana-or-orange/training_set/'
epochs = 1000
num_batch = 32
num_buffer = 60000

print(f"Will generate a resolution of {gen_res}.")
print(f"Will generate {gen_square}px square images.")
print(f"Will generate {img_chan} image channels.")
print(f"Will generate {img_rows} preview rows.")
print(f"Will generate {img_cols} preview columns.")
print(f"Our preview margin equals {img_margin}.")
print(f"Our data path is: {data_path}.")
print(f"Our number of epochs are: {epochs}.")
print(f"Will generate a batch size of {num_batch}.")
print(f"Will generate a buffer size of {num_buffer}.")
# Out:
# Will generate a resolution of 3.
# Will generate 96px square images.
# Will generate 3 image channels.
# Will generate 5 preview rows.
# Will generate 5 preview columns.
# Our preview margin equals 16.
# Our data path is: /content/drive/MyDrive/Datasets/banana-or-orange/training_set/.
# Our number of epochs are: 1000.
# Will generate a batch size of 32.
# Will generate a buffer size of 60000.

# %%
training_binary_path = os.path.join(data_path,
        f'training_data_{gen_square}_{gen_square}.npy')

print(f"Looking for file: {training_binary_path}")

if not os.path.isfile(training_binary_path):
  start = time.time()
  print("Loading training images...")

  train_data = []
  images_path = os.path.join(data_path,'banana')
  for filename in tqdm(os.listdir(images_path)):
      path = os.path.join(images_path,filename)
      images = Image.open(path).resize((gen_square,
            gen_square),Image.ANTIALIAS)
      train_data.append(np.asarray(images))
  train_data = np.reshape(train_data,(-1,gen_square,
            gen_square,img_chan))
  train_data = train_data.astype(np.float32)
  train_data = train_data / 127.5 - 1.


  print("Saving training image binary...")
  np.save(training_binary_path,train_data)
  elapsed = time.time()-start
  print (f'Image preprocess time: {hms_string(elapsed)}')
else:
  print("Loading training data...")
  train_data = np.load(training_binary_path)
# Out:
# Looking for file: /content/drive/MyDrive/Datasets/banana-or-orange/training_set/training_data_96_96.npy
# Loading training data...

# %%
train_dataset = tf.data.Dataset.from_tensor_slices(train_data) \
    .shuffle(num_buffer).batch(num_batch)

# %% [markdown]
# ## **Build the Generator and Discrminator**

# %%
def create_generator(seed_size, channels):
    model = Sequential()

    model.add(Dense(4*4*256,activation="relu",input_dim=seed_size))
    model.add(Reshape((4,4,256)))

    model.add(UpSampling2D())
    model.add(Conv2D(256,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))

    model.add(UpSampling2D())
    model.add(Conv2D(256,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))
   
    # Output resolution, additional upsampling
    model.add(UpSampling2D())
    model.add(Conv2D(128,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))

    if gen_res>1:
      model.add(UpSampling2D(size=(gen_res,gen_res)))
      model.add(Conv2D(128,kernel_size=3,padding="same"))
      model.add(BatchNormalization(momentum=0.8))
      model.add(Activation("relu"))

    # Final CNN layer
    model.add(Conv2D(channels,kernel_size=3,padding="same"))
    model.add(Activation("tanh"))

    return model


def create_discriminator(image_shape):
    model = Sequential()

    model.add(Conv2D(32, kernel_size=3, strides=2, input_shape=image_shape, 
                     padding="same"))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(64, kernel_size=3, strides=2, padding="same"))
    model.add(ZeroPadding2D(padding=((0,1),(0,1))))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(128, kernel_size=3, strides=2, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(256, kernel_size=3, strides=1, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(512, kernel_size=3, strides=1, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(1, activation='sigmoid'))

    return model

# %%
def save_images(cnt,noise):
  img_array = np.full(( 
      img_margin + (img_rows * (gen_square+img_margin)), 
      img_margin + (img_cols * (gen_square+img_margin)), 3), 
      255, dtype=np.uint8)
  
  gen_imgs = generator.predict(noise)

  gen_imgs = 0.5 * gen_imgs + 0.5

  img_count = 0
  for row in range(img_rows):
      for col in range(img_cols):
        r = row * (gen_square+16) + img_margin
        c = col * (gen_square+16) + img_margin
        img_array[r:r+gen_square,c:c+gen_square] \
            = gen_imgs[img_count] * 255
        img_count += 1

          
  output_path = os.path.join(data_path,'output')
  if not os.path.exists(output_path):
    os.makedirs(output_path)
  
  filename = os.path.join(output_path,f"train-{cnt}.png")
  im = Image.fromarray(img_array)
  im.save(filename)

# %%
generator = create_generator(seed_vector, img_chan)

noise = tf.random.normal([1, seed_vector])
gen_img = generator(noise, training=False)

plt.imshow(gen_img[0, :, :, 0])

# %%
img_shape = (gen_square,gen_square,img_chan)

discriminator = create_discriminator(img_shape)
decision = discriminator(gen_img)
print (decision)
# Out:
# tf.Tensor([[0.50012577]], shape=(1, 1), dtype=float32)

# %%
cross_entropy = tf.keras.losses.BinaryCrossentropy()

def discrim_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss
    return total_loss

def gen_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

# %%
gen_optimizer = tf.keras.optimizers.Adam(1.5e-4,0.5)
disc_optimizer = tf.keras.optimizers.Adam(1.5e-4,0.5)

# %%
@tf.function
def train_step(images):
  seed = tf.random.normal([num_batch, seed_vector])

  with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
    gen_imgs = generator(seed, training=True)

    real_output = discriminator(images, training=True)
    fake_output = discriminator(gen_imgs, training=True)

    g_loss = gen_loss(fake_output)
    d_loss = discrim_loss(real_output, fake_output)
    

    gradients_of_generator = gen_tape.gradient(\
        g_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(\
        d_loss, discriminator.trainable_variables)

    gen_optimizer.apply_gradients(zip(
        gradients_of_generator, generator.trainable_variables))
    disc_optimizer.apply_gradients(zip(
        gradients_of_discriminator, 
        discriminator.trainable_variables))
  return g_loss,d_loss

# %%
def train(dataset, epochs):
  fixed_seed = np.random.normal(0, 1, (img_rows * img_cols, 
                                       seed_vector))
  start = time.time()

  for epoch in range(epochs):
    epoch_start = time.time()

    g_loss_list = []
    d_loss_list = []

    for image_batch in dataset:
      t = train_step(image_batch)
      g_loss_list.append(t[0])
      d_loss_list.append(t[1])

    generator_loss = sum(g_loss_list) / len(g_loss_list)
    discriminator_loss = sum(d_loss_list) / len(d_loss_list)

    epoch_elapsed = time.time()-epoch_start
    print (f'Epoch {epoch+1}, gen loss={generator_loss},disc loss={discriminator_loss},'\
           ' {hms_string(epoch_elapsed)}')
    save_images(epoch,fixed_seed)

  elapsed = time.time()-start
  print (f'Training time: {hms_string(elapsed)}')

# %%
train(train_dataset, epochs)
# Out:
# Epoch 1, gen loss=0.8556491136550903,disc loss=1.2793333530426025, {hms_string(epoch_elapsed)}
# Epoch 2, gen loss=2.3814215660095215,disc loss=0.5236967206001282, {hms_string(epoch_elapsed)}
# Epoch 3, gen loss=2.9713330268859863,disc loss=0.1915840208530426, {hms_string(epoch_elapsed)}
# Epoch 4, gen loss=2.661672592163086,disc loss=0.21589595079421997, {hms_string(epoch_elapsed)}
# Epoch 5, gen loss=3.4123687744140625,disc loss=0.2514139413833618, {hms_string(epoch_elapsed)}
# Epoch 6, gen loss=2.758016586303711,disc loss=0.17609158158302307, {hms_string(epoch_elapsed)}
# Epoch 7, gen loss=4.213891983032227,disc loss=0.178836852312088, {hms_string(epoch_elapsed)}
# Epoch 8, gen loss=3.2230944633483887,disc loss=0.15835881233215332, {hms_string(epoch_elapsed)}
# Epoch 9, gen loss=3.5109002590179443,disc loss=0.1349879801273346, {hms_string(epoch_elapsed)}
# Epoch 10, gen loss=3.2415871620178223,disc loss=0.22426694631576538, {hms_string(epoch_elapsed)}
# Epoch 11, gen loss=4.121020793914795,disc loss=0.2672276794910431, {hms_string(epoch_elapsed)}
# Epoch 12, gen loss=3.5423405170440674,disc loss=0.20186716318130493, {hms_string(epoch_elapsed)}
# Epoch 13, gen loss=2.986563205718994,disc loss=0.25998926162719727, {hms_string(epoch_elapsed)}
# Epoch 14, gen loss=3.673112154006958,disc loss=0.30302631855010986, {hms_string(epoch_elapsed)}
# Epoch 15, gen loss=4.371735572814941,disc loss=0.1820974200963974, {hms_string(epoch_elapsed)}
# Epoch 16, gen loss=3.8374905586242676,disc loss=0.14596135914325714, {hms_string(epoch_elapsed)}
# Epoch 17, gen loss=4.483300685882568,disc loss=0.1455327421426773, {hms_string(epoch_elapsed)}
# Epoch 18, gen loss=4.351896286010742,disc loss=0.1401623636484146, {hms_string(epoch_elapsed)}
# Epoch 19, gen loss=4.815722465515137,disc loss=0.15403950214385986, {hms_string(epoch_elapsed)}
# Epoch 20, gen loss=4.229813098907471,disc loss=0.222098708152771, {hms_string(epoch_elapsed)}
# Epoch 21, gen loss=4.112674236297607,disc loss=0.15892143547534943, {hms_string(epoch_elapsed)}
# Epoch 22, gen loss=3.2551677227020264,disc loss=0.7073329091072083, {hms_string(epoch_elapsed)}
# Epoch 23, gen loss=4.6409807205200195,disc loss=1.2196264266967773, {hms_string(epoch_elapsed)}
# Epoch 24, gen loss=6.014726638793945,disc loss=0.11828291416168213, {hms_string(epoch_elapsed)}
# Epoch 25, gen loss=4.812241077423096,disc loss=0.11265166103839874, {hms_string(epoch_elapsed)}
# Epoch 26, gen loss=4.133553981781006,disc loss=0.16679427027702332, {hms_string(epoch_elapsed)}
# Epoch 27, gen loss=4.388932228088379,disc loss=0.2294623851776123, {hms_string(epoch_elapsed)}
# Epoch 28, gen loss=3.8514204025268555,disc loss=0.1794494241476059, {hms_string(epoch_elapsed)}
# Epoch 29, gen loss=3.7156689167022705,disc loss=0.27767646312713623, {hms_string(epoch_elapsed)}
# Epoch 30, gen loss=3.7805001735687256,disc loss=0.36376744508743286, {hms_string(epoch_elapsed)}
# Epoch 31, gen loss=4.6480865478515625,disc loss=0.4201451539993286, {hms_string(epoch_elapsed)}
# Epoch 32, gen loss=4.260841369628906,disc loss=0.2833043038845062, {hms_string(epoch_elapsed)}
# Epoch 33, gen loss=3.657104969024658,disc loss=0.2801586985588074, {hms_string(epoch_elapsed)}
# Epoch 34, gen loss=3.7014975547790527,disc loss=0.28377726674079895, {hms_string(epoch_elapsed)}
# Epoch 35, gen loss=3.3785581588745117,disc loss=0.6954445838928223, {hms_string(epoch_elapsed)}
# Epoch 36, gen loss=5.654855251312256,disc loss=3.30644154548645, {hms_string(epoch_elapsed)}
# Epoch 37, gen loss=2.0546627044677734,disc loss=0.6430120468139648, {hms_string(epoch_elapsed)}
# Epoch 38, gen loss=4.542916297912598,disc loss=0.4468289017677307, {hms_string(epoch_elapsed)}
# Epoch 39, gen loss=3.4441893100738525,disc loss=0.44839683175086975, {hms_string(epoch_elapsed)}
# Epoch 40, gen loss=3.6112148761749268,disc loss=0.45127058029174805, {hms_string(epoch_elapsed)}
# Epoch 41, gen loss=3.790876865386963,disc loss=0.7800239324569702, {hms_string(epoch_elapsed)}
# Epoch 42, gen loss=3.2055773735046387,disc loss=0.500922679901123, {hms_string(epoch_elapsed)}
# Epoch 43, gen loss=3.382918119430542,disc loss=0.445607990026474, {hms_string(epoch_elapsed)}
# Epoch 44, gen loss=3.878371238708496,disc loss=0.2485242486000061, {hms_string(epoch_elapsed)}
# Epoch 45, gen loss=3.2880330085754395,disc loss=0.476002037525177, {hms_string(epoch_elapsed)}
# Epoch 46, gen loss=3.5720858573913574,disc loss=0.5532585382461548, {hms_string(epoch_elapsed)}
# Epoch 47, gen loss=2.8372507095336914,disc loss=1.268355131149292, {hms_string(epoch_elapsed)}
# Epoch 48, gen loss=4.367990493774414,disc loss=1.061326503753662, {hms_string(epoch_elapsed)}
# Epoch 49, gen loss=3.7161049842834473,disc loss=0.3744874596595764, {hms_string(epoch_elapsed)}
# Epoch 50, gen loss=3.4403393268585205,disc loss=0.4162496328353882, {hms_string(epoch_elapsed)}
# Epoch 51, gen loss=3.867871046066284,disc loss=0.4277806282043457, {hms_string(epoch_elapsed)}
# Epoch 52, gen loss=3.087277889251709,disc loss=0.3514362573623657, {hms_string(epoch_elapsed)}
# Epoch 53, gen loss=2.7474966049194336,disc loss=0.521827757358551, {hms_string(epoch_elapsed)}
# Epoch 54, gen loss=3.6840996742248535,disc loss=0.5040790438652039, {hms_string(epoch_elapsed)}
# Epoch 55, gen loss=3.135693073272705,disc loss=0.3846926689147949, {hms_string(epoch_elapsed)}
# Epoch 56, gen loss=3.4255692958831787,disc loss=0.38343703746795654, {hms_string(epoch_elapsed)}
# Epoch 57, gen loss=3.19154953956604,disc loss=0.5743027925491333, {hms_string(epoch_elapsed)}
# Epoch 58, gen loss=3.105977773666382,disc loss=0.4440416097640991, {hms_string(epoch_elapsed)}
# Epoch 59, gen loss=3.4439949989318848,disc loss=1.0503379106521606, {hms_string(epoch_elapsed)}
# Epoch 60, gen loss=5.0621867179870605,disc loss=0.6283730864524841, {hms_string(epoch_elapsed)}
# Epoch 61, gen loss=3.261197090148926,disc loss=1.8532510995864868, {hms_string(epoch_elapsed)}
# Epoch 62, gen loss=2.8410043716430664,disc loss=0.5319022536277771, {hms_string(epoch_elapsed)}
# Epoch 63, gen loss=3.610136032104492,disc loss=0.6727199554443359, {hms_string(epoch_elapsed)}
# Epoch 64, gen loss=4.2569260597229,disc loss=0.9425902366638184, {hms_string(epoch_elapsed)}
# Epoch 65, gen loss=2.3896484375,disc loss=0.9127178192138672, {hms_string(epoch_elapsed)}
# Epoch 66, gen loss=3.8288490772247314,disc loss=0.7281219363212585, {hms_string(epoch_elapsed)}
# Epoch 67, gen loss=2.9042978286743164,disc loss=0.3258015513420105, {hms_string(epoch_elapsed)}
# Epoch 68, gen loss=3.649853229522705,disc loss=0.6954244375228882, {hms_string(epoch_elapsed)}
# Epoch 69, gen loss=3.536266326904297,disc loss=0.5305761098861694, {hms_string(epoch_elapsed)}
# Epoch 70, gen loss=3.5217955112457275,disc loss=0.9627400636672974, {hms_string(epoch_elapsed)}
# Epoch 71, gen loss=2.7661170959472656,disc loss=0.5231098532676697, {hms_string(epoch_elapsed)}
# Epoch 72, gen loss=2.8598151206970215,disc loss=0.5014494061470032, {hms_string(epoch_elapsed)}
# Epoch 73, gen loss=4.3350324630737305,disc loss=0.5277606248855591, {hms_string(epoch_elapsed)}
# Epoch 74, gen loss=3.27876615524292,disc loss=0.2925992012023926, {hms_string(epoch_elapsed)}
# Epoch 75, gen loss=3.1838722229003906,disc loss=0.8745706677436829, {hms_string(epoch_elapsed)}
# Epoch 76, gen loss=2.8167526721954346,disc loss=0.7853245735168457, {hms_string(epoch_elapsed)}
# Epoch 77, gen loss=2.514432430267334,disc loss=0.589171826839447, {hms_string(epoch_elapsed)}
# Epoch 78, gen loss=3.155500650405884,disc loss=0.5597766637802124, {hms_string(epoch_elapsed)}
# Epoch 79, gen loss=3.454092025756836,disc loss=1.0352144241333008, {hms_string(epoch_elapsed)}
# Epoch 80, gen loss=2.1048736572265625,disc loss=0.5568038821220398, {hms_string(epoch_elapsed)}
# Epoch 81, gen loss=3.979196548461914,disc loss=0.3837065100669861, {hms_string(epoch_elapsed)}
# Epoch 82, gen loss=2.7514500617980957,disc loss=0.6184051036834717, {hms_string(epoch_elapsed)}
# Epoch 83, gen loss=2.8235621452331543,disc loss=0.5075720548629761, {hms_string(epoch_elapsed)}
# Epoch 84, gen loss=3.372955560684204,disc loss=0.4236714839935303, {hms_string(epoch_elapsed)}
# Epoch 85, gen loss=2.9135122299194336,disc loss=0.5214130878448486, {hms_string(epoch_elapsed)}
# Epoch 86, gen loss=2.7252655029296875,disc loss=0.47229519486427307, {hms_string(epoch_elapsed)}
# Epoch 87, gen loss=3.0827503204345703,disc loss=1.48002290725708, {hms_string(epoch_elapsed)}
# Epoch 88, gen loss=4.113033294677734,disc loss=0.669739305973053, {hms_string(epoch_elapsed)}
# Epoch 89, gen loss=2.4792003631591797,disc loss=0.3902730941772461, {hms_string(epoch_elapsed)}
# Epoch 90, gen loss=3.751546859741211,disc loss=0.5556336641311646, {hms_string(epoch_elapsed)}
# Epoch 91, gen loss=3.352998971939087,disc loss=0.9561803936958313, {hms_string(epoch_elapsed)}
# Epoch 92, gen loss=3.393477439880371,disc loss=0.5341078042984009, {hms_string(epoch_elapsed)}
# Epoch 93, gen loss=2.6024668216705322,disc loss=0.47652143239974976, {hms_string(epoch_elapsed)}
# Epoch 94, gen loss=2.8407952785491943,disc loss=1.226820945739746, {hms_string(epoch_elapsed)}
# Epoch 95, gen loss=4.421042442321777,disc loss=0.4508800208568573, {hms_string(epoch_elapsed)}
# Epoch 96, gen loss=2.7391586303710938,disc loss=0.38584646582603455, {hms_string(epoch_elapsed)}
# Epoch 97, gen loss=3.889406204223633,disc loss=0.5312665700912476, {hms_string(epoch_elapsed)}
# Epoch 98, gen loss=2.388573169708252,disc loss=0.5539488792419434, {hms_string(epoch_elapsed)}
# Epoch 99, gen loss=3.3502519130706787,disc loss=0.4770762324333191, {hms_string(epoch_elapsed)}
# Epoch 100, gen loss=3.2480902671813965,disc loss=0.4348081946372986, {hms_string(epoch_elapsed)}
# Epoch 101, gen loss=3.2230424880981445,disc loss=0.5605095624923706, {hms_string(epoch_elapsed)}
# Epoch 102, gen loss=4.624416351318359,disc loss=0.2925776243209839, {hms_string(epoch_elapsed)}
# Epoch 103, gen loss=3.026823043823242,disc loss=0.29996782541275024, {hms_string(epoch_elapsed)}
# Epoch 104, gen loss=3.975576400756836,disc loss=0.5332813262939453, {hms_string(epoch_elapsed)}
# Epoch 105, gen loss=3.7173380851745605,disc loss=0.3760295510292053, {hms_string(epoch_elapsed)}
# Epoch 106, gen loss=3.7054250240325928,disc loss=0.408843457698822, {hms_string(epoch_elapsed)}
# Epoch 107, gen loss=4.957736968994141,disc loss=0.39978688955307007, {hms_string(epoch_elapsed)}
# Epoch 108, gen loss=2.8838887214660645,disc loss=0.9391049146652222, {hms_string(epoch_elapsed)}
# Epoch 109, gen loss=3.052936315536499,disc loss=0.5121704339981079, {hms_string(epoch_elapsed)}
# Epoch 110, gen loss=3.502899408340454,disc loss=0.6579127311706543, {hms_string(epoch_elapsed)}
# Epoch 111, gen loss=4.067440032958984,disc loss=0.37266412377357483, {hms_string(epoch_elapsed)}
# Epoch 112, gen loss=3.1222360134124756,disc loss=0.3666906952857971, {hms_string(epoch_elapsed)}
# Epoch 113, gen loss=3.652198314666748,disc loss=0.6941096782684326, {hms_string(epoch_elapsed)}
# Epoch 114, gen loss=3.4009335041046143,disc loss=0.5323631763458252, {hms_string(epoch_elapsed)}
# Epoch 115, gen loss=2.988279342651367,disc loss=0.587261974811554, {hms_string(epoch_elapsed)}
# Epoch 116, gen loss=3.8249363899230957,disc loss=0.7994375228881836, {hms_string(epoch_elapsed)}
# Epoch 117, gen loss=3.7029802799224854,disc loss=0.5298104882240295, {hms_string(epoch_elapsed)}
# Epoch 118, gen loss=2.9267349243164062,disc loss=0.49937379360198975, {hms_string(epoch_elapsed)}
# Epoch 119, gen loss=3.6643269062042236,disc loss=0.5651432871818542, {hms_string(epoch_elapsed)}
# Epoch 120, gen loss=3.536879062652588,disc loss=0.42030271887779236, {hms_string(epoch_elapsed)}
# Epoch 121, gen loss=3.1244640350341797,disc loss=0.5887186527252197, {hms_string(epoch_elapsed)}
# Epoch 122, gen loss=4.749382972717285,disc loss=0.33536040782928467, {hms_string(epoch_elapsed)}
# Epoch 123, gen loss=2.9331865310668945,disc loss=0.4056071937084198, {hms_string(epoch_elapsed)}
# Epoch 124, gen loss=3.746790885925293,disc loss=0.46678590774536133, {hms_string(epoch_elapsed)}
# Epoch 125, gen loss=3.0221219062805176,disc loss=0.4863010048866272, {hms_string(epoch_elapsed)}
# Epoch 126, gen loss=3.857196807861328,disc loss=0.34012457728385925, {hms_string(epoch_elapsed)}
# Epoch 127, gen loss=3.5084047317504883,disc loss=0.4226076602935791, {hms_string(epoch_elapsed)}
# Epoch 128, gen loss=3.9385721683502197,disc loss=0.5428622364997864, {hms_string(epoch_elapsed)}
# Epoch 129, gen loss=3.5683727264404297,disc loss=0.5265544652938843, {hms_string(epoch_elapsed)}
# Epoch 130, gen loss=3.671190023422241,disc loss=0.32097044587135315, {hms_string(epoch_elapsed)}
# Epoch 131, gen loss=4.3931074142456055,disc loss=0.4756297469139099, {hms_string(epoch_elapsed)}
# Epoch 132, gen loss=3.861279010772705,disc loss=0.30886030197143555, {hms_string(epoch_elapsed)}
# Epoch 133, gen loss=4.496271133422852,disc loss=0.23503367602825165, {hms_string(epoch_elapsed)}
# Epoch 134, gen loss=3.7378525733947754,disc loss=0.4974897801876068, {hms_string(epoch_elapsed)}
# Epoch 135, gen loss=2.884436845779419,disc loss=0.3295643627643585, {hms_string(epoch_elapsed)}
# Epoch 136, gen loss=4.949443817138672,disc loss=0.47950834035873413, {hms_string(epoch_elapsed)}
# Epoch 137, gen loss=3.5085670948028564,disc loss=0.4487801492214203, {hms_string(epoch_elapsed)}
# Epoch 138, gen loss=4.106941223144531,disc loss=0.32259872555732727, {hms_string(epoch_elapsed)}
# Epoch 139, gen loss=3.2393603324890137,disc loss=0.6620090007781982, {hms_string(epoch_elapsed)}
# Epoch 140, gen loss=3.6891837120056152,disc loss=0.9317869544029236, {hms_string(epoch_elapsed)}
# Epoch 141, gen loss=4.7835373878479,disc loss=0.37263941764831543, {hms_string(epoch_elapsed)}
# Epoch 142, gen loss=3.6096208095550537,disc loss=0.46572184562683105, {hms_string(epoch_elapsed)}
# Epoch 143, gen loss=4.37721586227417,disc loss=0.36298346519470215, {hms_string(epoch_elapsed)}
# Epoch 144, gen loss=3.3569016456604004,disc loss=0.6362888813018799, {hms_string(epoch_elapsed)}
# Epoch 145, gen loss=4.581721305847168,disc loss=0.4258349537849426, {hms_string(epoch_elapsed)}
# Epoch 146, gen loss=3.1929149627685547,disc loss=0.4919879734516144, {hms_string(epoch_elapsed)}
# Epoch 147, gen loss=3.2681093215942383,disc loss=0.5519617795944214, {hms_string(epoch_elapsed)}
# Epoch 148, gen loss=4.179170608520508,disc loss=0.4235369563102722, {hms_string(epoch_elapsed)}
# Epoch 149, gen loss=3.628520965576172,disc loss=0.4393882155418396, {hms_string(epoch_elapsed)}
# Epoch 150, gen loss=3.756570816040039,disc loss=0.5313385725021362, {hms_string(epoch_elapsed)}
# Epoch 151, gen loss=3.608477830886841,disc loss=0.4332594871520996, {hms_string(epoch_elapsed)}
# Epoch 152, gen loss=4.1532816886901855,disc loss=0.32044002413749695, {hms_string(epoch_elapsed)}
# Epoch 153, gen loss=2.848850965499878,disc loss=0.592902660369873, {hms_string(epoch_elapsed)}
# Epoch 154, gen loss=4.208675861358643,disc loss=0.6308228969573975, {hms_string(epoch_elapsed)}
# Epoch 155, gen loss=4.107777118682861,disc loss=0.35677170753479004, {hms_string(epoch_elapsed)}
# Epoch 156, gen loss=3.4858222007751465,disc loss=0.5308705568313599, {hms_string(epoch_elapsed)}
# Epoch 157, gen loss=3.3291544914245605,disc loss=0.31992095708847046, {hms_string(epoch_elapsed)}
# Epoch 158, gen loss=4.128935813903809,disc loss=0.2756183445453644, {hms_string(epoch_elapsed)}
# Epoch 159, gen loss=3.9345483779907227,disc loss=0.22465774416923523, {hms_string(epoch_elapsed)}
# Epoch 160, gen loss=3.8457183837890625,disc loss=0.29240283370018005, {hms_string(epoch_elapsed)}
# Epoch 161, gen loss=3.587554931640625,disc loss=0.46539631485939026, {hms_string(epoch_elapsed)}
# Epoch 162, gen loss=4.220332622528076,disc loss=0.4230458736419678, {hms_string(epoch_elapsed)}
# Epoch 163, gen loss=4.03975248336792,disc loss=0.37276023626327515, {hms_string(epoch_elapsed)}
# Epoch 164, gen loss=2.899000406265259,disc loss=0.4780958890914917, {hms_string(epoch_elapsed)}
# Epoch 165, gen loss=4.660478115081787,disc loss=0.45084112882614136, {hms_string(epoch_elapsed)}
# Epoch 166, gen loss=4.385029315948486,disc loss=0.8533422946929932, {hms_string(epoch_elapsed)}
# Epoch 167, gen loss=2.863931179046631,disc loss=0.43407484889030457, {hms_string(epoch_elapsed)}
# Epoch 168, gen loss=4.8404998779296875,disc loss=0.3619016110897064, {hms_string(epoch_elapsed)}
# Epoch 169, gen loss=4.003074645996094,disc loss=0.44797277450561523, {hms_string(epoch_elapsed)}
# Epoch 170, gen loss=3.7677154541015625,disc loss=0.4411107897758484, {hms_string(epoch_elapsed)}
# Epoch 171, gen loss=4.213233470916748,disc loss=0.49603593349456787, {hms_string(epoch_elapsed)}
# Epoch 172, gen loss=3.764744997024536,disc loss=0.36293989419937134, {hms_string(epoch_elapsed)}
# Epoch 173, gen loss=4.591157913208008,disc loss=0.3061319589614868, {hms_string(epoch_elapsed)}
# Epoch 174, gen loss=4.3731279373168945,disc loss=0.3667646050453186, {hms_string(epoch_elapsed)}
# Epoch 175, gen loss=3.4592761993408203,disc loss=0.27355146408081055, {hms_string(epoch_elapsed)}
# Epoch 176, gen loss=4.684840202331543,disc loss=0.32128360867500305, {hms_string(epoch_elapsed)}
# Epoch 177, gen loss=4.150568008422852,disc loss=0.6222546100616455, {hms_string(epoch_elapsed)}
# Epoch 178, gen loss=3.85001540184021,disc loss=0.33965837955474854, {hms_string(epoch_elapsed)}
# Epoch 179, gen loss=3.8056249618530273,disc loss=0.5516543984413147, {hms_string(epoch_elapsed)}
# Epoch 180, gen loss=5.027095794677734,disc loss=0.28709471225738525, {hms_string(epoch_elapsed)}
# Epoch 181, gen loss=4.361933708190918,disc loss=0.22839757800102234, {hms_string(epoch_elapsed)}
# Epoch 182, gen loss=4.941650390625,disc loss=0.23800456523895264, {hms_string(epoch_elapsed)}
# Epoch 183, gen loss=3.434617519378662,disc loss=0.4253445863723755, {hms_string(epoch_elapsed)}
# Epoch 184, gen loss=3.6257193088531494,disc loss=0.34945550560951233, {hms_string(epoch_elapsed)}
# Epoch 185, gen loss=4.104222774505615,disc loss=0.45417308807373047, {hms_string(epoch_elapsed)}
# Epoch 186, gen loss=4.129763603210449,disc loss=0.40620604157447815, {hms_string(epoch_elapsed)}
# Epoch 187, gen loss=3.885103464126587,disc loss=0.5068034529685974, {hms_string(epoch_elapsed)}
# Epoch 188, gen loss=4.202537536621094,disc loss=0.2925637364387512, {hms_string(epoch_elapsed)}
# Epoch 189, gen loss=4.228113174438477,disc loss=0.34636998176574707, {hms_string(epoch_elapsed)}
# Epoch 190, gen loss=3.9741275310516357,disc loss=0.3734864890575409, {hms_string(epoch_elapsed)}
# Epoch 191, gen loss=2.713582992553711,disc loss=0.5756506323814392, {hms_string(epoch_elapsed)}
# Epoch 192, gen loss=4.482906341552734,disc loss=0.4884302616119385, {hms_string(epoch_elapsed)}
# Epoch 193, gen loss=3.516390323638916,disc loss=0.3649616837501526, {hms_string(epoch_elapsed)}
# Epoch 194, gen loss=4.9790120124816895,disc loss=0.7612013816833496, {hms_string(epoch_elapsed)}
# Epoch 195, gen loss=3.227233409881592,disc loss=0.4483923316001892, {hms_string(epoch_elapsed)}
# Epoch 196, gen loss=4.519265174865723,disc loss=0.4031660556793213, {hms_string(epoch_elapsed)}
# Epoch 197, gen loss=4.469674110412598,disc loss=0.6556627750396729, {hms_string(epoch_elapsed)}
# Epoch 198, gen loss=3.9734017848968506,disc loss=0.396867960691452, {hms_string(epoch_elapsed)}
# Epoch 199, gen loss=3.95959210395813,disc loss=0.4752119779586792, {hms_string(epoch_elapsed)}
# Epoch 200, gen loss=3.7827367782592773,disc loss=0.5030841827392578, {hms_string(epoch_elapsed)}
# Epoch 201, gen loss=4.745145797729492,disc loss=0.8602896332740784, {hms_string(epoch_elapsed)}
# Epoch 202, gen loss=3.6358559131622314,disc loss=0.5384091138839722, {hms_string(epoch_elapsed)}
# Epoch 203, gen loss=4.996465682983398,disc loss=0.4852949380874634, {hms_string(epoch_elapsed)}
# Epoch 204, gen loss=4.299295425415039,disc loss=0.7266755104064941, {hms_string(epoch_elapsed)}
# Epoch 205, gen loss=4.138815402984619,disc loss=0.30491989850997925, {hms_string(epoch_elapsed)}
# Epoch 206, gen loss=4.362092971801758,disc loss=0.7265597581863403, {hms_string(epoch_elapsed)}
# Epoch 207, gen loss=4.0022873878479,disc loss=0.3083571791648865, {hms_string(epoch_elapsed)}
# Epoch 208, gen loss=3.5745441913604736,disc loss=0.3872089684009552, {hms_string(epoch_elapsed)}
# Epoch 209, gen loss=4.5246500968933105,disc loss=0.49448299407958984, {hms_string(epoch_elapsed)}
# Epoch 210, gen loss=3.7388129234313965,disc loss=0.3567754626274109, {hms_string(epoch_elapsed)}
# Epoch 211, gen loss=3.9127073287963867,disc loss=0.5005796551704407, {hms_string(epoch_elapsed)}
# Epoch 212, gen loss=4.526172161102295,disc loss=0.5679342746734619, {hms_string(epoch_elapsed)}
# Epoch 213, gen loss=4.187463283538818,disc loss=0.8273980617523193, {hms_string(epoch_elapsed)}
# Epoch 214, gen loss=3.863579750061035,disc loss=0.36239922046661377, {hms_string(epoch_elapsed)}
# Epoch 215, gen loss=4.18558406829834,disc loss=0.3227223753929138, {hms_string(epoch_elapsed)}
# Epoch 216, gen loss=4.425363540649414,disc loss=0.47473400831222534, {hms_string(epoch_elapsed)}
# Epoch 217, gen loss=3.7598211765289307,disc loss=0.3780953586101532, {hms_string(epoch_elapsed)}
# Epoch 218, gen loss=4.904082298278809,disc loss=0.3406413197517395, {hms_string(epoch_elapsed)}
# Epoch 219, gen loss=4.2859649658203125,disc loss=0.4158666729927063, {hms_string(epoch_elapsed)}
# Epoch 220, gen loss=4.29470157623291,disc loss=0.2850114107131958, {hms_string(epoch_elapsed)}
# Epoch 221, gen loss=4.011351585388184,disc loss=0.5757484436035156, {hms_string(epoch_elapsed)}
# Epoch 222, gen loss=4.909130573272705,disc loss=1.5153559446334839, {hms_string(epoch_elapsed)}
# Epoch 223, gen loss=2.2150747776031494,disc loss=0.8057777881622314, {hms_string(epoch_elapsed)}
# Epoch 224, gen loss=5.5092453956604,disc loss=1.2694333791732788, {hms_string(epoch_elapsed)}
# Epoch 225, gen loss=4.248240947723389,disc loss=0.5628737807273865, {hms_string(epoch_elapsed)}
# Epoch 226, gen loss=3.5807127952575684,disc loss=0.33450716733932495, {hms_string(epoch_elapsed)}
# Epoch 227, gen loss=3.674967050552368,disc loss=0.4579429030418396, {hms_string(epoch_elapsed)}
# Epoch 228, gen loss=4.174639701843262,disc loss=0.3386361002922058, {hms_string(epoch_elapsed)}
# Epoch 229, gen loss=3.950704336166382,disc loss=0.27018454670906067, {hms_string(epoch_elapsed)}
# Epoch 230, gen loss=4.524552822113037,disc loss=0.18335148692131042, {hms_string(epoch_elapsed)}
# Epoch 231, gen loss=4.086840629577637,disc loss=0.33728933334350586, {hms_string(epoch_elapsed)}
# Epoch 232, gen loss=5.9854230880737305,disc loss=0.2506811320781708, {hms_string(epoch_elapsed)}
# Epoch 233, gen loss=3.826735496520996,disc loss=0.7225388884544373, {hms_string(epoch_elapsed)}
# Epoch 234, gen loss=3.936800956726074,disc loss=0.39454224705696106, {hms_string(epoch_elapsed)}
# Epoch 235, gen loss=5.163732051849365,disc loss=0.35644030570983887, {hms_string(epoch_elapsed)}
# Epoch 236, gen loss=3.1105809211730957,disc loss=0.3890182673931122, {hms_string(epoch_elapsed)}
# Epoch 237, gen loss=4.121909141540527,disc loss=0.5090464353561401, {hms_string(epoch_elapsed)}
# Epoch 238, gen loss=3.951085090637207,disc loss=0.22863058745861053, {hms_string(epoch_elapsed)}
# Epoch 239, gen loss=4.35512113571167,disc loss=0.42181944847106934, {hms_string(epoch_elapsed)}
# Epoch 240, gen loss=4.818759918212891,disc loss=0.22472651302814484, {hms_string(epoch_elapsed)}
# Epoch 241, gen loss=4.081650733947754,disc loss=0.2761359214782715, {hms_string(epoch_elapsed)}
# Epoch 242, gen loss=4.410723686218262,disc loss=0.2190864235162735, {hms_string(epoch_elapsed)}
# Epoch 243, gen loss=4.491229057312012,disc loss=0.235352024435997, {hms_string(epoch_elapsed)}
# Epoch 244, gen loss=3.9921841621398926,disc loss=0.4266166090965271, {hms_string(epoch_elapsed)}
# Epoch 245, gen loss=3.2712271213531494,disc loss=0.4028259217739105, {hms_string(epoch_elapsed)}
# Epoch 246, gen loss=4.063518524169922,disc loss=0.3221255838871002, {hms_string(epoch_elapsed)}
# Epoch 247, gen loss=3.6272497177124023,disc loss=0.2921544015407562, {hms_string(epoch_elapsed)}
# Epoch 248, gen loss=4.242376327514648,disc loss=0.40016746520996094, {hms_string(epoch_elapsed)}
# Epoch 249, gen loss=3.8440945148468018,disc loss=0.5835236310958862, {hms_string(epoch_elapsed)}
# Epoch 250, gen loss=4.344213485717773,disc loss=0.9687768220901489, {hms_string(epoch_elapsed)}
# Epoch 251, gen loss=4.935110092163086,disc loss=0.2616227865219116, {hms_string(epoch_elapsed)}
# Epoch 252, gen loss=3.168511390686035,disc loss=0.22572922706604004, {hms_string(epoch_elapsed)}
# Epoch 253, gen loss=4.469254016876221,disc loss=0.5610069036483765, {hms_string(epoch_elapsed)}
# Epoch 254, gen loss=3.6281590461730957,disc loss=0.5488658547401428, {hms_string(epoch_elapsed)}
# Epoch 255, gen loss=3.943324089050293,disc loss=0.2145978808403015, {hms_string(epoch_elapsed)}
# Epoch 256, gen loss=4.15255069732666,disc loss=0.40569591522216797, {hms_string(epoch_elapsed)}
# Epoch 257, gen loss=2.936044692993164,disc loss=0.39296823740005493, {hms_string(epoch_elapsed)}
# Epoch 258, gen loss=4.262825012207031,disc loss=0.2540825605392456, {hms_string(epoch_elapsed)}
# Epoch 259, gen loss=4.790591239929199,disc loss=0.732099711894989, {hms_string(epoch_elapsed)}
# Epoch 260, gen loss=3.44216251373291,disc loss=0.5410847663879395, {hms_string(epoch_elapsed)}
# Epoch 261, gen loss=3.8080551624298096,disc loss=0.5000073909759521, {hms_string(epoch_elapsed)}
# Epoch 262, gen loss=3.9225287437438965,disc loss=0.510387659072876, {hms_string(epoch_elapsed)}
# Epoch 263, gen loss=4.380382537841797,disc loss=0.32107681035995483, {hms_string(epoch_elapsed)}
# Epoch 264, gen loss=3.959409475326538,disc loss=0.3727281987667084, {hms_string(epoch_elapsed)}
# Epoch 265, gen loss=3.729001760482788,disc loss=0.24218234419822693, {hms_string(epoch_elapsed)}
# Epoch 266, gen loss=4.071828842163086,disc loss=0.2566525638103485, {hms_string(epoch_elapsed)}
# Epoch 267, gen loss=4.247302532196045,disc loss=0.366920530796051, {hms_string(epoch_elapsed)}
# Epoch 268, gen loss=4.513384819030762,disc loss=0.5645334720611572, {hms_string(epoch_elapsed)}
# Epoch 269, gen loss=3.4784698486328125,disc loss=0.36474090814590454, {hms_string(epoch_elapsed)}
# Epoch 270, gen loss=4.189165115356445,disc loss=0.4738363027572632, {hms_string(epoch_elapsed)}
# Epoch 271, gen loss=4.838932991027832,disc loss=0.3103242516517639, {hms_string(epoch_elapsed)}
# Epoch 272, gen loss=3.8987765312194824,disc loss=0.32329168915748596, {hms_string(epoch_elapsed)}
# Epoch 273, gen loss=3.963418483734131,disc loss=0.30411458015441895, {hms_string(epoch_elapsed)}
# Epoch 274, gen loss=4.284002304077148,disc loss=0.16062627732753754, {hms_string(epoch_elapsed)}
# Epoch 275, gen loss=4.28907585144043,disc loss=0.43771177530288696, {hms_string(epoch_elapsed)}
# Epoch 276, gen loss=4.030909538269043,disc loss=0.5541846752166748, {hms_string(epoch_elapsed)}
# Epoch 277, gen loss=3.344348907470703,disc loss=0.37449800968170166, {hms_string(epoch_elapsed)}
# Epoch 278, gen loss=4.030438423156738,disc loss=0.5514400005340576, {hms_string(epoch_elapsed)}
# Epoch 279, gen loss=4.205265998840332,disc loss=0.4472021758556366, {hms_string(epoch_elapsed)}
# Epoch 280, gen loss=3.8602638244628906,disc loss=0.3884618878364563, {hms_string(epoch_elapsed)}
# Epoch 281, gen loss=3.7024078369140625,disc loss=0.41479912400245667, {hms_string(epoch_elapsed)}
# Epoch 282, gen loss=3.8830313682556152,disc loss=0.2517178952693939, {hms_string(epoch_elapsed)}
# Epoch 283, gen loss=4.535672187805176,disc loss=0.3431127965450287, {hms_string(epoch_elapsed)}
# Epoch 284, gen loss=3.8765294551849365,disc loss=0.3041006028652191, {hms_string(epoch_elapsed)}
# Epoch 285, gen loss=4.175107479095459,disc loss=0.2549596130847931, {hms_string(epoch_elapsed)}
# Epoch 286, gen loss=4.935221195220947,disc loss=0.5320518016815186, {hms_string(epoch_elapsed)}
# Epoch 287, gen loss=5.7394514083862305,disc loss=2.074434995651245, {hms_string(epoch_elapsed)}
# Epoch 288, gen loss=3.302089214324951,disc loss=0.4583881199359894, {hms_string(epoch_elapsed)}
# Epoch 289, gen loss=4.161460876464844,disc loss=0.1874953806400299, {hms_string(epoch_elapsed)}
# Epoch 290, gen loss=3.8320651054382324,disc loss=0.19170333445072174, {hms_string(epoch_elapsed)}
# Epoch 291, gen loss=3.911470890045166,disc loss=0.39319273829460144, {hms_string(epoch_elapsed)}
# Epoch 292, gen loss=3.942610025405884,disc loss=0.5150893926620483, {hms_string(epoch_elapsed)}
# Epoch 293, gen loss=2.6326236724853516,disc loss=0.5265458822250366, {hms_string(epoch_elapsed)}
# Epoch 294, gen loss=6.009971618652344,disc loss=0.7755772471427917, {hms_string(epoch_elapsed)}
# Epoch 295, gen loss=4.61113166809082,disc loss=0.8619296550750732, {hms_string(epoch_elapsed)}
# Epoch 296, gen loss=2.9479095935821533,disc loss=0.560274064540863, {hms_string(epoch_elapsed)}
# Epoch 297, gen loss=4.7010602951049805,disc loss=0.2925173044204712, {hms_string(epoch_elapsed)}
# Epoch 298, gen loss=3.994706153869629,disc loss=0.23606938123703003, {hms_string(epoch_elapsed)}
# Epoch 299, gen loss=4.626006603240967,disc loss=0.30069050192832947, {hms_string(epoch_elapsed)}
# Epoch 300, gen loss=3.531420946121216,disc loss=0.3279854953289032, {hms_string(epoch_elapsed)}
# Epoch 301, gen loss=3.8274502754211426,disc loss=0.5204253196716309, {hms_string(epoch_elapsed)}
# Epoch 302, gen loss=4.997215270996094,disc loss=0.4433344602584839, {hms_string(epoch_elapsed)}
# Epoch 303, gen loss=5.0570068359375,disc loss=1.0415449142456055, {hms_string(epoch_elapsed)}
# Epoch 304, gen loss=3.0580673217773438,disc loss=0.24817663431167603, {hms_string(epoch_elapsed)}
# Epoch 305, gen loss=5.3227434158325195,disc loss=0.35128992795944214, {hms_string(epoch_elapsed)}
# Epoch 306, gen loss=3.701782464981079,disc loss=0.3403659462928772, {hms_string(epoch_elapsed)}
# Epoch 307, gen loss=5.139432907104492,disc loss=0.32016950845718384, {hms_string(epoch_elapsed)}
# Epoch 308, gen loss=4.804516792297363,disc loss=0.5858154296875, {hms_string(epoch_elapsed)}
# Epoch 309, gen loss=3.6515018939971924,disc loss=0.284348726272583, {hms_string(epoch_elapsed)}
# Epoch 310, gen loss=3.576882839202881,disc loss=0.444855272769928, {hms_string(epoch_elapsed)}
# Epoch 311, gen loss=5.962576389312744,disc loss=0.42140331864356995, {hms_string(epoch_elapsed)}
# Epoch 312, gen loss=5.310408115386963,disc loss=1.7840001583099365, {hms_string(epoch_elapsed)}
# Epoch 313, gen loss=3.2175939083099365,disc loss=0.45911380648612976, {hms_string(epoch_elapsed)}
# Epoch 314, gen loss=4.957314968109131,disc loss=0.32439377903938293, {hms_string(epoch_elapsed)}
# Epoch 315, gen loss=4.330325126647949,disc loss=0.3493879437446594, {hms_string(epoch_elapsed)}
# Epoch 316, gen loss=3.4465785026550293,disc loss=0.3078944683074951, {hms_string(epoch_elapsed)}
# Epoch 317, gen loss=5.174356460571289,disc loss=0.5059168934822083, {hms_string(epoch_elapsed)}
# Epoch 318, gen loss=4.580287456512451,disc loss=0.26372063159942627, {hms_string(epoch_elapsed)}
# Epoch 319, gen loss=4.076061248779297,disc loss=0.2941807210445404, {hms_string(epoch_elapsed)}
# Epoch 320, gen loss=4.111511707305908,disc loss=0.21499648690223694, {hms_string(epoch_elapsed)}
# Epoch 321, gen loss=4.316586494445801,disc loss=0.2428843080997467, {hms_string(epoch_elapsed)}
# Epoch 322, gen loss=4.411452293395996,disc loss=0.33225777745246887, {hms_string(epoch_elapsed)}
# Epoch 323, gen loss=4.674375534057617,disc loss=0.16826416552066803, {hms_string(epoch_elapsed)}
# Epoch 324, gen loss=4.613542556762695,disc loss=0.17309048771858215, {hms_string(epoch_elapsed)}
# Epoch 325, gen loss=3.3657665252685547,disc loss=0.2984844446182251, {hms_string(epoch_elapsed)}
# Epoch 326, gen loss=4.799460411071777,disc loss=0.853800356388092, {hms_string(epoch_elapsed)}
# Epoch 327, gen loss=4.804206371307373,disc loss=0.3363651633262634, {hms_string(epoch_elapsed)}
# Epoch 328, gen loss=4.1190104484558105,disc loss=0.2573699355125427, {hms_string(epoch_elapsed)}
# Epoch 329, gen loss=3.8364474773406982,disc loss=0.27586811780929565, {hms_string(epoch_elapsed)}
# Epoch 330, gen loss=4.326228141784668,disc loss=0.28369948267936707, {hms_string(epoch_elapsed)}
# Epoch 331, gen loss=3.5340986251831055,disc loss=0.3609089255332947, {hms_string(epoch_elapsed)}
# Epoch 332, gen loss=4.362814903259277,disc loss=0.34900355339050293, {hms_string(epoch_elapsed)}
# Epoch 333, gen loss=3.924884796142578,disc loss=0.31499868631362915, {hms_string(epoch_elapsed)}
# Epoch 334, gen loss=3.812427520751953,disc loss=0.2549765706062317, {hms_string(epoch_elapsed)}
# Epoch 335, gen loss=3.8162739276885986,disc loss=0.30294182896614075, {hms_string(epoch_elapsed)}
# Epoch 336, gen loss=3.815736770629883,disc loss=0.2891607880592346, {hms_string(epoch_elapsed)}
# Epoch 337, gen loss=3.8396339416503906,disc loss=0.4232841730117798, {hms_string(epoch_elapsed)}
# Epoch 338, gen loss=4.633159637451172,disc loss=0.24009422957897186, {hms_string(epoch_elapsed)}
# Epoch 339, gen loss=4.195898056030273,disc loss=0.2820398807525635, {hms_string(epoch_elapsed)}
# Epoch 340, gen loss=4.397000312805176,disc loss=0.37331193685531616, {hms_string(epoch_elapsed)}
# Epoch 341, gen loss=6.674070835113525,disc loss=2.437856912612915, {hms_string(epoch_elapsed)}
# Epoch 342, gen loss=2.163583755493164,disc loss=0.8146920204162598, {hms_string(epoch_elapsed)}
# Epoch 343, gen loss=7.348310470581055,disc loss=0.737370491027832, {hms_string(epoch_elapsed)}
# Epoch 344, gen loss=3.750230312347412,disc loss=0.26739177107810974, {hms_string(epoch_elapsed)}
# Epoch 345, gen loss=5.164773941040039,disc loss=0.1787828803062439, {hms_string(epoch_elapsed)}
# Epoch 346, gen loss=3.599341869354248,disc loss=0.3021768629550934, {hms_string(epoch_elapsed)}
# Epoch 347, gen loss=4.653524875640869,disc loss=0.2625434994697571, {hms_string(epoch_elapsed)}
# Epoch 348, gen loss=4.022242546081543,disc loss=0.5095644593238831, {hms_string(epoch_elapsed)}
# Epoch 349, gen loss=4.007478713989258,disc loss=0.27625003457069397, {hms_string(epoch_elapsed)}
# Epoch 350, gen loss=3.8529648780822754,disc loss=0.4032953083515167, {hms_string(epoch_elapsed)}
# Epoch 351, gen loss=4.615278720855713,disc loss=0.19750642776489258, {hms_string(epoch_elapsed)}
# Epoch 352, gen loss=5.287209510803223,disc loss=0.2828768491744995, {hms_string(epoch_elapsed)}
# Epoch 353, gen loss=4.270232200622559,disc loss=0.2162272036075592, {hms_string(epoch_elapsed)}
# Epoch 354, gen loss=4.727250099182129,disc loss=0.3810139000415802, {hms_string(epoch_elapsed)}
# Epoch 355, gen loss=3.906248092651367,disc loss=0.3353450894355774, {hms_string(epoch_elapsed)}
# Epoch 356, gen loss=5.631677627563477,disc loss=0.27329176664352417, {hms_string(epoch_elapsed)}
# Epoch 357, gen loss=3.8539726734161377,disc loss=0.3613073229789734, {hms_string(epoch_elapsed)}
# Epoch 358, gen loss=5.365549087524414,disc loss=0.16652652621269226, {hms_string(epoch_elapsed)}
# Epoch 359, gen loss=4.223034858703613,disc loss=0.30059459805488586, {hms_string(epoch_elapsed)}
# Epoch 360, gen loss=5.124425888061523,disc loss=0.1421135663986206, {hms_string(epoch_elapsed)}
# Epoch 361, gen loss=4.210529327392578,disc loss=0.12638339400291443, {hms_string(epoch_elapsed)}
# Epoch 362, gen loss=3.688009023666382,disc loss=0.2343832105398178, {hms_string(epoch_elapsed)}
# Epoch 363, gen loss=3.971132516860962,disc loss=0.32094812393188477, {hms_string(epoch_elapsed)}
# Epoch 364, gen loss=3.8829073905944824,disc loss=0.3363454043865204, {hms_string(epoch_elapsed)}
# Epoch 365, gen loss=3.868553400039673,disc loss=0.32451367378234863, {hms_string(epoch_elapsed)}
# Epoch 366, gen loss=3.7184624671936035,disc loss=0.30877935886383057, {hms_string(epoch_elapsed)}
# Epoch 367, gen loss=5.14288330078125,disc loss=0.21734945476055145, {hms_string(epoch_elapsed)}
# Epoch 368, gen loss=3.984980344772339,disc loss=0.19363707304000854, {hms_string(epoch_elapsed)}
# Epoch 369, gen loss=4.5259246826171875,disc loss=0.15566232800483704, {hms_string(epoch_elapsed)}
# Epoch 370, gen loss=3.154407024383545,disc loss=0.5016978979110718, {hms_string(epoch_elapsed)}
# Epoch 371, gen loss=4.973428726196289,disc loss=0.46336454153060913, {hms_string(epoch_elapsed)}
# Epoch 372, gen loss=4.193392753601074,disc loss=0.21235868334770203, {hms_string(epoch_elapsed)}
# Epoch 373, gen loss=4.621370792388916,disc loss=0.1359422206878662, {hms_string(epoch_elapsed)}
# Epoch 374, gen loss=4.590539932250977,disc loss=0.17184054851531982, {hms_string(epoch_elapsed)}
# Epoch 375, gen loss=4.3571953773498535,disc loss=0.6145926117897034, {hms_string(epoch_elapsed)}
# Epoch 376, gen loss=5.636149883270264,disc loss=1.7359353303909302, {hms_string(epoch_elapsed)}
# Epoch 377, gen loss=2.1330392360687256,disc loss=0.7333508729934692, {hms_string(epoch_elapsed)}
# Epoch 378, gen loss=6.137454032897949,disc loss=0.6936430335044861, {hms_string(epoch_elapsed)}
# Epoch 379, gen loss=4.121368408203125,disc loss=0.3530243933200836, {hms_string(epoch_elapsed)}
# Epoch 380, gen loss=4.86100435256958,disc loss=0.4219188988208771, {hms_string(epoch_elapsed)}
# Epoch 381, gen loss=4.4628801345825195,disc loss=0.6072695255279541, {hms_string(epoch_elapsed)}
# Epoch 382, gen loss=4.974796295166016,disc loss=0.2918629050254822, {hms_string(epoch_elapsed)}
# Epoch 383, gen loss=4.290460586547852,disc loss=0.247808039188385, {hms_string(epoch_elapsed)}
# Epoch 384, gen loss=4.426541328430176,disc loss=0.2270861566066742, {hms_string(epoch_elapsed)}
# Epoch 385, gen loss=4.348783493041992,disc loss=0.31792739033699036, {hms_string(epoch_elapsed)}
# Epoch 386, gen loss=4.360661506652832,disc loss=0.2886624336242676, {hms_string(epoch_elapsed)}
# Epoch 387, gen loss=3.33034086227417,disc loss=0.30227309465408325, {hms_string(epoch_elapsed)}
# Epoch 388, gen loss=4.442523956298828,disc loss=0.349101722240448, {hms_string(epoch_elapsed)}
# Epoch 389, gen loss=4.6460113525390625,disc loss=0.2238699346780777, {hms_string(epoch_elapsed)}
# Epoch 390, gen loss=4.247190952301025,disc loss=0.2825480103492737, {hms_string(epoch_elapsed)}
# Epoch 391, gen loss=4.339104175567627,disc loss=0.2974356412887573, {hms_string(epoch_elapsed)}
# Epoch 392, gen loss=3.676999568939209,disc loss=0.22786085307598114, {hms_string(epoch_elapsed)}
# Epoch 393, gen loss=5.290326118469238,disc loss=0.23824916779994965, {hms_string(epoch_elapsed)}
# Epoch 394, gen loss=4.082749366760254,disc loss=0.17744207382202148, {hms_string(epoch_elapsed)}
# Epoch 395, gen loss=5.13286018371582,disc loss=0.22939254343509674, {hms_string(epoch_elapsed)}
# Epoch 396, gen loss=3.921792984008789,disc loss=0.2797375023365021, {hms_string(epoch_elapsed)}
# Epoch 397, gen loss=4.418553352355957,disc loss=0.1512978971004486, {hms_string(epoch_elapsed)}
# Epoch 398, gen loss=5.235830307006836,disc loss=0.26254063844680786, {hms_string(epoch_elapsed)}
# Epoch 399, gen loss=4.953533172607422,disc loss=0.9976593852043152, {hms_string(epoch_elapsed)}
# Epoch 400, gen loss=3.76589298248291,disc loss=0.40523406863212585, {hms_string(epoch_elapsed)}
# Epoch 401, gen loss=4.335572719573975,disc loss=0.213004007935524, {hms_string(epoch_elapsed)}
# Epoch 402, gen loss=3.6704633235931396,disc loss=0.21755777299404144, {hms_string(epoch_elapsed)}
# Epoch 403, gen loss=4.767612934112549,disc loss=0.4455373287200928, {hms_string(epoch_elapsed)}
# Epoch 404, gen loss=4.556203842163086,disc loss=0.2812367379665375, {hms_string(epoch_elapsed)}
# Epoch 405, gen loss=4.8404059410095215,disc loss=0.42663976550102234, {hms_string(epoch_elapsed)}
# Epoch 406, gen loss=4.295252799987793,disc loss=0.45718705654144287, {hms_string(epoch_elapsed)}
# Epoch 407, gen loss=3.613144874572754,disc loss=0.2930629253387451, {hms_string(epoch_elapsed)}
# Epoch 408, gen loss=4.555734157562256,disc loss=0.18772423267364502, {hms_string(epoch_elapsed)}
# Epoch 409, gen loss=3.8158061504364014,disc loss=0.25471988320350647, {hms_string(epoch_elapsed)}
# Epoch 410, gen loss=4.044617176055908,disc loss=0.24894604086875916, {hms_string(epoch_elapsed)}
# Epoch 411, gen loss=4.8882646560668945,disc loss=0.3726981282234192, {hms_string(epoch_elapsed)}
# Epoch 412, gen loss=3.5205464363098145,disc loss=0.26661765575408936, {hms_string(epoch_elapsed)}
# Epoch 413, gen loss=4.449638366699219,disc loss=0.13393312692642212, {hms_string(epoch_elapsed)}
# Epoch 414, gen loss=4.662235260009766,disc loss=0.20719821751117706, {hms_string(epoch_elapsed)}
# Epoch 415, gen loss=4.494899272918701,disc loss=0.21415463089942932, {hms_string(epoch_elapsed)}
# Epoch 416, gen loss=4.605295658111572,disc loss=0.17411881685256958, {hms_string(epoch_elapsed)}
# Epoch 417, gen loss=4.977529525756836,disc loss=0.4646225571632385, {hms_string(epoch_elapsed)}
# Epoch 418, gen loss=3.6422910690307617,disc loss=0.26491332054138184, {hms_string(epoch_elapsed)}
# Epoch 419, gen loss=4.905387878417969,disc loss=0.26074856519699097, {hms_string(epoch_elapsed)}
# Epoch 420, gen loss=4.28175163269043,disc loss=0.38856902718544006, {hms_string(epoch_elapsed)}
# Epoch 421, gen loss=4.792340278625488,disc loss=0.35235846042633057, {hms_string(epoch_elapsed)}
# Epoch 422, gen loss=4.726395606994629,disc loss=0.3214729130268097, {hms_string(epoch_elapsed)}
# Epoch 423, gen loss=4.477797031402588,disc loss=0.36962592601776123, {hms_string(epoch_elapsed)}
# Epoch 424, gen loss=3.6190972328186035,disc loss=0.3435570299625397, {hms_string(epoch_elapsed)}
# Epoch 425, gen loss=4.915005683898926,disc loss=0.30202943086624146, {hms_string(epoch_elapsed)}
# Epoch 426, gen loss=4.461566925048828,disc loss=0.38217300176620483, {hms_string(epoch_elapsed)}
# Epoch 427, gen loss=4.477499961853027,disc loss=0.20412510633468628, {hms_string(epoch_elapsed)}
# Epoch 428, gen loss=4.242146015167236,disc loss=0.31619274616241455, {hms_string(epoch_elapsed)}
# Epoch 429, gen loss=3.464949131011963,disc loss=0.28470703959465027, {hms_string(epoch_elapsed)}
# Epoch 430, gen loss=4.092021465301514,disc loss=0.962591290473938, {hms_string(epoch_elapsed)}
# Epoch 431, gen loss=6.972246170043945,disc loss=1.273113489151001, {hms_string(epoch_elapsed)}
# Epoch 432, gen loss=4.5322675704956055,disc loss=0.6993863582611084, {hms_string(epoch_elapsed)}
# Epoch 433, gen loss=4.679405689239502,disc loss=0.4212561547756195, {hms_string(epoch_elapsed)}
# Epoch 434, gen loss=4.800746917724609,disc loss=0.3948458433151245, {hms_string(epoch_elapsed)}
# Epoch 435, gen loss=5.4599714279174805,disc loss=1.0349135398864746, {hms_string(epoch_elapsed)}
# Epoch 436, gen loss=4.253459453582764,disc loss=0.34624210000038147, {hms_string(epoch_elapsed)}
# Epoch 437, gen loss=4.151348114013672,disc loss=0.2989841103553772, {hms_string(epoch_elapsed)}
# Epoch 438, gen loss=4.752477645874023,disc loss=1.1379461288452148, {hms_string(epoch_elapsed)}
# Epoch 439, gen loss=6.374797821044922,disc loss=0.45274949073791504, {hms_string(epoch_elapsed)}
# Epoch 440, gen loss=3.624933958053589,disc loss=0.4951525926589966, {hms_string(epoch_elapsed)}
# Epoch 441, gen loss=5.528328895568848,disc loss=0.31838521361351013, {hms_string(epoch_elapsed)}
# Epoch 442, gen loss=4.110434532165527,disc loss=0.2665552794933319, {hms_string(epoch_elapsed)}
# Epoch 443, gen loss=4.473654747009277,disc loss=0.1792965978384018, {hms_string(epoch_elapsed)}
# Epoch 444, gen loss=4.56550931930542,disc loss=0.14108535647392273, {hms_string(epoch_elapsed)}
# Epoch 445, gen loss=4.64321231842041,disc loss=0.28611305356025696, {hms_string(epoch_elapsed)}
# Epoch 446, gen loss=4.425905227661133,disc loss=0.31397879123687744, {hms_string(epoch_elapsed)}
# Epoch 447, gen loss=4.289426326751709,disc loss=0.26523178815841675, {hms_string(epoch_elapsed)}
# Epoch 448, gen loss=4.603463172912598,disc loss=0.20591893792152405, {hms_string(epoch_elapsed)}
# Epoch 449, gen loss=4.397092819213867,disc loss=0.2152840495109558, {hms_string(epoch_elapsed)}
# Epoch 450, gen loss=4.073387145996094,disc loss=0.1628267467021942, {hms_string(epoch_elapsed)}
# Epoch 451, gen loss=5.085825443267822,disc loss=0.3057044744491577, {hms_string(epoch_elapsed)}
# Epoch 452, gen loss=3.875375747680664,disc loss=0.295090913772583, {hms_string(epoch_elapsed)}
# Epoch 453, gen loss=5.041444778442383,disc loss=0.29497814178466797, {hms_string(epoch_elapsed)}
# Epoch 454, gen loss=4.357418060302734,disc loss=0.1849226951599121, {hms_string(epoch_elapsed)}
# Epoch 455, gen loss=4.330894470214844,disc loss=0.1694074273109436, {hms_string(epoch_elapsed)}
# Epoch 456, gen loss=4.8780317306518555,disc loss=0.3458588421344757, {hms_string(epoch_elapsed)}
# Epoch 457, gen loss=3.3268826007843018,disc loss=0.7880444526672363, {hms_string(epoch_elapsed)}
# Epoch 458, gen loss=4.976659774780273,disc loss=0.33459657430648804, {hms_string(epoch_elapsed)}
# Epoch 459, gen loss=4.657127380371094,disc loss=0.18361826241016388, {hms_string(epoch_elapsed)}
# Epoch 460, gen loss=4.843020439147949,disc loss=0.10481850802898407, {hms_string(epoch_elapsed)}
# Epoch 461, gen loss=4.104962348937988,disc loss=0.25798898935317993, {hms_string(epoch_elapsed)}
# Epoch 462, gen loss=4.630517959594727,disc loss=0.3727808892726898, {hms_string(epoch_elapsed)}
# Epoch 463, gen loss=4.965081214904785,disc loss=0.5350849628448486, {hms_string(epoch_elapsed)}
# Epoch 464, gen loss=3.644650459289551,disc loss=0.288780152797699, {hms_string(epoch_elapsed)}
# Epoch 465, gen loss=3.672752618789673,disc loss=0.5908123254776001, {hms_string(epoch_elapsed)}
# Epoch 466, gen loss=5.531785011291504,disc loss=0.4788334369659424, {hms_string(epoch_elapsed)}
# Epoch 467, gen loss=4.387280464172363,disc loss=0.2708183825016022, {hms_string(epoch_elapsed)}
# Epoch 468, gen loss=4.835394859313965,disc loss=0.14572936296463013, {hms_string(epoch_elapsed)}
# Epoch 469, gen loss=4.631012916564941,disc loss=0.21312284469604492, {hms_string(epoch_elapsed)}
# Epoch 470, gen loss=3.9609198570251465,disc loss=0.23260241746902466, {hms_string(epoch_elapsed)}
# Epoch 471, gen loss=4.308764934539795,disc loss=0.3521434962749481, {hms_string(epoch_elapsed)}
# Epoch 472, gen loss=4.971238613128662,disc loss=0.27961406111717224, {hms_string(epoch_elapsed)}
# Epoch 473, gen loss=3.537160873413086,disc loss=0.5686215162277222, {hms_string(epoch_elapsed)}
# Epoch 474, gen loss=5.177504539489746,disc loss=0.23242661356925964, {hms_string(epoch_elapsed)}
# Epoch 475, gen loss=3.5936317443847656,disc loss=0.20436948537826538, {hms_string(epoch_elapsed)}
# Epoch 476, gen loss=4.881568908691406,disc loss=0.2961046099662781, {hms_string(epoch_elapsed)}
# Epoch 477, gen loss=3.953835964202881,disc loss=0.16888439655303955, {hms_string(epoch_elapsed)}
# Epoch 478, gen loss=4.868317604064941,disc loss=0.18878230452537537, {hms_string(epoch_elapsed)}
# Epoch 479, gen loss=4.509396553039551,disc loss=0.44226327538490295, {hms_string(epoch_elapsed)}
# Epoch 480, gen loss=5.188516616821289,disc loss=0.33287930488586426, {hms_string(epoch_elapsed)}
# Epoch 481, gen loss=4.073419570922852,disc loss=0.3622336983680725, {hms_string(epoch_elapsed)}
# Epoch 482, gen loss=3.6555683612823486,disc loss=0.8155601024627686, {hms_string(epoch_elapsed)}
# Epoch 483, gen loss=6.761070251464844,disc loss=0.3628007173538208, {hms_string(epoch_elapsed)}
# Epoch 484, gen loss=4.291162490844727,disc loss=0.5010806322097778, {hms_string(epoch_elapsed)}
# Epoch 485, gen loss=3.9371280670166016,disc loss=0.6082839369773865, {hms_string(epoch_elapsed)}
# Epoch 486, gen loss=4.2495269775390625,disc loss=0.49234825372695923, {hms_string(epoch_elapsed)}
# Epoch 487, gen loss=4.406614780426025,disc loss=0.34838318824768066, {hms_string(epoch_elapsed)}
# Epoch 488, gen loss=3.9378905296325684,disc loss=0.21616597473621368, {hms_string(epoch_elapsed)}
# Epoch 489, gen loss=5.568566799163818,disc loss=0.3405800461769104, {hms_string(epoch_elapsed)}
# Epoch 490, gen loss=4.132565021514893,disc loss=0.2705479562282562, {hms_string(epoch_elapsed)}
# Epoch 491, gen loss=4.063009262084961,disc loss=0.20586180686950684, {hms_string(epoch_elapsed)}
# Epoch 492, gen loss=4.667864799499512,disc loss=0.41953739523887634, {hms_string(epoch_elapsed)}
# Epoch 493, gen loss=4.133428573608398,disc loss=0.2097630798816681, {hms_string(epoch_elapsed)}
# Epoch 494, gen loss=4.731744289398193,disc loss=0.4077131748199463, {hms_string(epoch_elapsed)}
# Epoch 495, gen loss=5.841860771179199,disc loss=0.1758364737033844, {hms_string(epoch_elapsed)}
# Epoch 496, gen loss=4.362812042236328,disc loss=0.2473457157611847, {hms_string(epoch_elapsed)}
# Epoch 497, gen loss=3.9100704193115234,disc loss=0.5103284120559692, {hms_string(epoch_elapsed)}
# Epoch 498, gen loss=5.399195671081543,disc loss=0.34187769889831543, {hms_string(epoch_elapsed)}
# ...
# Epoch 836, gen loss=3.9753570556640625,disc loss=0.29374662041664124, {hms_string(epoch_elapsed)}
# Epoch 837, gen loss=4.4319562911987305,disc loss=0.2743951082229614, {hms_string(epoch_elapsed)}
# Epoch 838, gen loss=5.621494770050049,disc loss=0.06891222298145294, {hms_string(epoch_elapsed)}
# Epoch 839, gen loss=4.769242763519287,disc loss=0.327248752117157, {hms_string(epoch_elapsed)}
# Epoch 840, gen loss=4.271129608154297,disc loss=0.5938324332237244, {hms_string(epoch_elapsed)}
# Epoch 841, gen loss=5.516473770141602,disc loss=0.510892391204834, {hms_string(epoch_elapsed)}
# Epoch 842, gen loss=5.243872165679932,disc loss=0.29403674602508545, {hms_string(epoch_elapsed)}
# Epoch 843, gen loss=4.804147243499756,disc loss=1.4974457025527954, {hms_string(epoch_elapsed)}
# Epoch 844, gen loss=7.169260025024414,disc loss=1.048996090888977, {hms_string(epoch_elapsed)}
# Epoch 845, gen loss=2.7474985122680664,disc loss=0.9389514923095703, {hms_string(epoch_elapsed)}
# Epoch 846, gen loss=6.830028057098389,disc loss=0.39843282103538513, {hms_string(epoch_elapsed)}
# Epoch 847, gen loss=4.002347946166992,disc loss=0.3030243217945099, {hms_string(epoch_elapsed)}
# Epoch 848, gen loss=5.278146743774414,disc loss=0.39153409004211426, {hms_string(epoch_elapsed)}
# Epoch 849, gen loss=4.28983211517334,disc loss=0.3145171105861664, {hms_string(epoch_elapsed)}
# Epoch 850, gen loss=4.667458534240723,disc loss=0.296347439289093, {hms_string(epoch_elapsed)}
# Epoch 851, gen loss=5.893338680267334,disc loss=0.30766451358795166, {hms_string(epoch_elapsed)}
# Epoch 852, gen loss=3.687077045440674,disc loss=0.4082610011100769, {hms_string(epoch_elapsed)}
# Epoch 853, gen loss=4.963042259216309,disc loss=0.27510911226272583, {hms_string(epoch_elapsed)}
# Epoch 854, gen loss=4.064798355102539,disc loss=0.2094818651676178, {hms_string(epoch_elapsed)}
# Epoch 855, gen loss=4.324674606323242,disc loss=0.3331223726272583, {hms_string(epoch_elapsed)}
# Epoch 856, gen loss=4.745860576629639,disc loss=0.32250359654426575, {hms_string(epoch_elapsed)}
# Epoch 857, gen loss=4.319707870483398,disc loss=0.25274011492729187, {hms_string(epoch_elapsed)}
# Epoch 858, gen loss=4.701805114746094,disc loss=0.3897411823272705, {hms_string(epoch_elapsed)}
# Epoch 859, gen loss=4.286612033843994,disc loss=0.6591945290565491, {hms_string(epoch_elapsed)}
# Epoch 860, gen loss=6.000194549560547,disc loss=0.32196173071861267, {hms_string(epoch_elapsed)}
# Epoch 861, gen loss=4.195947170257568,disc loss=0.33707237243652344, {hms_string(epoch_elapsed)}
# Epoch 862, gen loss=4.755397319793701,disc loss=0.29129067063331604, {hms_string(epoch_elapsed)}
# Epoch 863, gen loss=4.8372087478637695,disc loss=0.208794966340065, {hms_string(epoch_elapsed)}
# Epoch 864, gen loss=4.394510269165039,disc loss=0.24317176640033722, {hms_string(epoch_elapsed)}
# Epoch 865, gen loss=4.9608154296875,disc loss=0.3445892333984375, {hms_string(epoch_elapsed)}
# Epoch 866, gen loss=4.989923477172852,disc loss=0.3610060214996338, {hms_string(epoch_elapsed)}
# Epoch 867, gen loss=4.355121612548828,disc loss=0.4678841233253479, {hms_string(epoch_elapsed)}
# Epoch 868, gen loss=4.592832088470459,disc loss=0.48437535762786865, {hms_string(epoch_elapsed)}
# Epoch 869, gen loss=6.068329811096191,disc loss=0.12893196940422058, {hms_string(epoch_elapsed)}
# Epoch 870, gen loss=4.987342834472656,disc loss=0.21712732315063477, {hms_string(epoch_elapsed)}
# Epoch 871, gen loss=4.78510856628418,disc loss=0.20710968971252441, {hms_string(epoch_elapsed)}
# Epoch 872, gen loss=4.192673683166504,disc loss=0.20636770129203796, {hms_string(epoch_elapsed)}
# Epoch 873, gen loss=5.597861289978027,disc loss=0.1569288671016693, {hms_string(epoch_elapsed)}
# Epoch 874, gen loss=5.230925559997559,disc loss=0.15167081356048584, {hms_string(epoch_elapsed)}
# Epoch 875, gen loss=5.314743995666504,disc loss=0.23294472694396973, {hms_string(epoch_elapsed)}
# Epoch 876, gen loss=4.696985721588135,disc loss=0.2018813192844391, {hms_string(epoch_elapsed)}
# Epoch 877, gen loss=4.6492919921875,disc loss=0.16087685525417328, {hms_string(epoch_elapsed)}
# Epoch 878, gen loss=5.481026649475098,disc loss=0.2131514698266983, {hms_string(epoch_elapsed)}
# Epoch 879, gen loss=4.766996383666992,disc loss=0.16168715059757233, {hms_string(epoch_elapsed)}
# Epoch 880, gen loss=4.153288841247559,disc loss=0.21957391500473022, {hms_string(epoch_elapsed)}
# Epoch 881, gen loss=5.121744155883789,disc loss=0.3127247989177704, {hms_string(epoch_elapsed)}
# Epoch 882, gen loss=4.088773250579834,disc loss=0.424805611371994, {hms_string(epoch_elapsed)}
# Epoch 883, gen loss=5.691192150115967,disc loss=0.5433684587478638, {hms_string(epoch_elapsed)}
# Epoch 884, gen loss=2.970578908920288,disc loss=0.6757069230079651, {hms_string(epoch_elapsed)}
# Epoch 885, gen loss=5.689016819000244,disc loss=0.5214900374412537, {hms_string(epoch_elapsed)}
# Epoch 886, gen loss=5.123793601989746,disc loss=0.3275340795516968, {hms_string(epoch_elapsed)}
# Epoch 887, gen loss=5.1072492599487305,disc loss=0.22169898450374603, {hms_string(epoch_elapsed)}
# Epoch 888, gen loss=4.160341739654541,disc loss=0.489817351102829, {hms_string(epoch_elapsed)}
# Epoch 889, gen loss=5.978448867797852,disc loss=0.4223504066467285, {hms_string(epoch_elapsed)}
# Epoch 890, gen loss=3.2293598651885986,disc loss=0.4491589069366455, {hms_string(epoch_elapsed)}
# Epoch 891, gen loss=5.552271842956543,disc loss=0.20965014398097992, {hms_string(epoch_elapsed)}
# Epoch 892, gen loss=4.240038871765137,disc loss=0.20002269744873047, {hms_string(epoch_elapsed)}
# Epoch 893, gen loss=4.681150436401367,disc loss=0.6083359122276306, {hms_string(epoch_elapsed)}
# Epoch 894, gen loss=4.414087772369385,disc loss=0.7984709739685059, {hms_string(epoch_elapsed)}
# Epoch 895, gen loss=3.8365345001220703,disc loss=0.4277499318122864, {hms_string(epoch_elapsed)}
# Epoch 896, gen loss=5.490873336791992,disc loss=0.402208149433136, {hms_string(epoch_elapsed)}
# Epoch 897, gen loss=4.485162734985352,disc loss=0.18487948179244995, {hms_string(epoch_elapsed)}
# Epoch 898, gen loss=4.38700532913208,disc loss=0.4238354563713074, {hms_string(epoch_elapsed)}
# Epoch 899, gen loss=5.228134632110596,disc loss=0.22047053277492523, {hms_string(epoch_elapsed)}
# Epoch 900, gen loss=4.769388198852539,disc loss=0.22293387353420258, {hms_string(epoch_elapsed)}
# Epoch 901, gen loss=4.737163066864014,disc loss=0.3318714499473572, {hms_string(epoch_elapsed)}
# Epoch 902, gen loss=4.517910957336426,disc loss=0.3761711120605469, {hms_string(epoch_elapsed)}
# Epoch 903, gen loss=4.86264705657959,disc loss=0.14802765846252441, {hms_string(epoch_elapsed)}
# Epoch 904, gen loss=4.865601062774658,disc loss=0.4190838932991028, {hms_string(epoch_elapsed)}
# Epoch 905, gen loss=4.615982532501221,disc loss=0.26043394207954407, {hms_string(epoch_elapsed)}
# Epoch 906, gen loss=5.616775989532471,disc loss=0.41738268733024597, {hms_string(epoch_elapsed)}
# Epoch 907, gen loss=3.7828569412231445,disc loss=0.4026734232902527, {hms_string(epoch_elapsed)}
# Epoch 908, gen loss=4.573986053466797,disc loss=0.2961428761482239, {hms_string(epoch_elapsed)}
# Epoch 909, gen loss=5.660659313201904,disc loss=0.24243375658988953, {hms_string(epoch_elapsed)}
# Epoch 910, gen loss=4.9124345779418945,disc loss=0.41742733120918274, {hms_string(epoch_elapsed)}
# Epoch 911, gen loss=5.172151565551758,disc loss=0.6187254190444946, {hms_string(epoch_elapsed)}
# Epoch 912, gen loss=4.585011005401611,disc loss=0.20700305700302124, {hms_string(epoch_elapsed)}
# Epoch 913, gen loss=5.728699207305908,disc loss=0.36828649044036865, {hms_string(epoch_elapsed)}
# Epoch 914, gen loss=4.789098739624023,disc loss=0.26867151260375977, {hms_string(epoch_elapsed)}
# Epoch 915, gen loss=5.4175310134887695,disc loss=0.30250540375709534, {hms_string(epoch_elapsed)}
# Epoch 916, gen loss=4.606982231140137,disc loss=0.3039114475250244, {hms_string(epoch_elapsed)}
# Epoch 917, gen loss=3.794224739074707,disc loss=0.33267807960510254, {hms_string(epoch_elapsed)}
# Epoch 918, gen loss=5.651751518249512,disc loss=0.3351024389266968, {hms_string(epoch_elapsed)}
# Epoch 919, gen loss=5.987573146820068,disc loss=0.32895681262016296, {hms_string(epoch_elapsed)}
# Epoch 920, gen loss=4.097809791564941,disc loss=0.4013633728027344, {hms_string(epoch_elapsed)}
# Epoch 921, gen loss=6.323246002197266,disc loss=0.36339259147644043, {hms_string(epoch_elapsed)}
# Epoch 922, gen loss=4.290844917297363,disc loss=0.3551068902015686, {hms_string(epoch_elapsed)}
# Epoch 923, gen loss=4.3011393547058105,disc loss=0.3179904520511627, {hms_string(epoch_elapsed)}
# Epoch 924, gen loss=5.371243000030518,disc loss=0.2453872412443161, {hms_string(epoch_elapsed)}
# Epoch 925, gen loss=4.035769462585449,disc loss=0.3583263158798218, {hms_string(epoch_elapsed)}
# Epoch 926, gen loss=4.809577941894531,disc loss=0.3225615620613098, {hms_string(epoch_elapsed)}
# Epoch 927, gen loss=3.845658779144287,disc loss=0.4593103528022766, {hms_string(epoch_elapsed)}
# Epoch 928, gen loss=6.203129291534424,disc loss=0.3768535256385803, {hms_string(epoch_elapsed)}
# Epoch 929, gen loss=3.201178550720215,disc loss=0.3856963515281677, {hms_string(epoch_elapsed)}
# Epoch 930, gen loss=5.652517318725586,disc loss=0.5733827352523804, {hms_string(epoch_elapsed)}
# Epoch 931, gen loss=3.5025296211242676,disc loss=0.6211585998535156, {hms_string(epoch_elapsed)}
# Epoch 932, gen loss=5.4924421310424805,disc loss=0.5096089839935303, {hms_string(epoch_elapsed)}
# Epoch 933, gen loss=4.421872138977051,disc loss=0.7739419937133789, {hms_string(epoch_elapsed)}
# Epoch 934, gen loss=4.664581775665283,disc loss=0.5346992015838623, {hms_string(epoch_elapsed)}
# Epoch 935, gen loss=5.315618515014648,disc loss=0.3159846067428589, {hms_string(epoch_elapsed)}
# Epoch 936, gen loss=4.650416851043701,disc loss=0.40945160388946533, {hms_string(epoch_elapsed)}
# Epoch 937, gen loss=4.703411102294922,disc loss=0.3704150319099426, {hms_string(epoch_elapsed)}
# Epoch 938, gen loss=4.464984893798828,disc loss=0.19467228651046753, {hms_string(epoch_elapsed)}
# Epoch 939, gen loss=5.637063026428223,disc loss=0.1780952662229538, {hms_string(epoch_elapsed)}
# Epoch 940, gen loss=4.699548244476318,disc loss=0.33837494254112244, {hms_string(epoch_elapsed)}
# Epoch 941, gen loss=5.310694217681885,disc loss=0.3030284643173218, {hms_string(epoch_elapsed)}
# Epoch 942, gen loss=4.623029708862305,disc loss=0.33668026328086853, {hms_string(epoch_elapsed)}
# Epoch 943, gen loss=5.497621536254883,disc loss=0.17827486991882324, {hms_string(epoch_elapsed)}
# Epoch 944, gen loss=4.244282245635986,disc loss=0.2190011739730835, {hms_string(epoch_elapsed)}
# Epoch 945, gen loss=5.233696937561035,disc loss=0.3453044891357422, {hms_string(epoch_elapsed)}
# Epoch 946, gen loss=3.580136299133301,disc loss=0.42623090744018555, {hms_string(epoch_elapsed)}
# Epoch 947, gen loss=5.970914840698242,disc loss=0.23247596621513367, {hms_string(epoch_elapsed)}
# Epoch 948, gen loss=3.3142895698547363,disc loss=0.29627710580825806, {hms_string(epoch_elapsed)}
# Epoch 949, gen loss=6.296217441558838,disc loss=0.3723863363265991, {hms_string(epoch_elapsed)}
# Epoch 950, gen loss=4.129406452178955,disc loss=0.4035884737968445, {hms_string(epoch_elapsed)}
# Epoch 951, gen loss=4.885397434234619,disc loss=0.3320472538471222, {hms_string(epoch_elapsed)}
# Epoch 952, gen loss=4.5238518714904785,disc loss=0.20241597294807434, {hms_string(epoch_elapsed)}
# Epoch 953, gen loss=5.066927433013916,disc loss=0.15914751589298248, {hms_string(epoch_elapsed)}
# Epoch 954, gen loss=5.0861592292785645,disc loss=0.4212718605995178, {hms_string(epoch_elapsed)}
# Epoch 955, gen loss=3.2184805870056152,disc loss=0.4320739507675171, {hms_string(epoch_elapsed)}
# Epoch 956, gen loss=5.752674102783203,disc loss=0.6632322669029236, {hms_string(epoch_elapsed)}
# Epoch 957, gen loss=5.830863952636719,disc loss=0.6580280661582947, {hms_string(epoch_elapsed)}
# Epoch 958, gen loss=3.016359806060791,disc loss=0.4212820529937744, {hms_string(epoch_elapsed)}
# Epoch 959, gen loss=6.198099136352539,disc loss=0.36645111441612244, {hms_string(epoch_elapsed)}
# Epoch 960, gen loss=5.271737098693848,disc loss=0.264952152967453, {hms_string(epoch_elapsed)}
# Epoch 961, gen loss=5.397923469543457,disc loss=0.27100491523742676, {hms_string(epoch_elapsed)}
# Epoch 962, gen loss=4.244822978973389,disc loss=0.30127382278442383, {hms_string(epoch_elapsed)}
# Epoch 963, gen loss=4.9308552742004395,disc loss=0.1636338233947754, {hms_string(epoch_elapsed)}
# Epoch 964, gen loss=6.021386623382568,disc loss=0.40219077467918396, {hms_string(epoch_elapsed)}
# Epoch 965, gen loss=4.579104423522949,disc loss=0.4517182409763336, {hms_string(epoch_elapsed)}
# Epoch 966, gen loss=5.165151119232178,disc loss=0.372435986995697, {hms_string(epoch_elapsed)}
# Epoch 967, gen loss=4.59956169128418,disc loss=0.14428451657295227, {hms_string(epoch_elapsed)}
# Epoch 968, gen loss=4.43731164932251,disc loss=0.30582380294799805, {hms_string(epoch_elapsed)}
# Epoch 969, gen loss=5.389939308166504,disc loss=0.20075318217277527, {hms_string(epoch_elapsed)}
# Epoch 970, gen loss=5.260542869567871,disc loss=0.23831230401992798, {hms_string(epoch_elapsed)}
# Epoch 971, gen loss=4.665782451629639,disc loss=0.1832677125930786, {hms_string(epoch_elapsed)}
# Epoch 972, gen loss=4.885068893432617,disc loss=0.24910968542099, {hms_string(epoch_elapsed)}
# Epoch 973, gen loss=4.405051231384277,disc loss=0.3637298345565796, {hms_string(epoch_elapsed)}
# Epoch 974, gen loss=5.681192398071289,disc loss=0.21379229426383972, {hms_string(epoch_elapsed)}
# Epoch 975, gen loss=4.644536018371582,disc loss=0.2238648533821106, {hms_string(epoch_elapsed)}
# Epoch 976, gen loss=5.4122443199157715,disc loss=0.1763412207365036, {hms_string(epoch_elapsed)}
# Epoch 977, gen loss=4.314353942871094,disc loss=0.2512505054473877, {hms_string(epoch_elapsed)}
# Epoch 978, gen loss=6.131317138671875,disc loss=0.20576657354831696, {hms_string(epoch_elapsed)}
# Epoch 979, gen loss=4.2369279861450195,disc loss=0.2833995223045349, {hms_string(epoch_elapsed)}
# Epoch 980, gen loss=4.985379695892334,disc loss=0.2495775818824768, {hms_string(epoch_elapsed)}
# Epoch 981, gen loss=5.08380651473999,disc loss=0.26265525817871094, {hms_string(epoch_elapsed)}
# Epoch 982, gen loss=4.184625625610352,disc loss=0.34256231784820557, {hms_string(epoch_elapsed)}
# Epoch 983, gen loss=5.39638090133667,disc loss=0.37521985173225403, {hms_string(epoch_elapsed)}
# Epoch 984, gen loss=4.706842422485352,disc loss=0.30651527643203735, {hms_string(epoch_elapsed)}
# Epoch 985, gen loss=4.702093124389648,disc loss=0.13663043081760406, {hms_string(epoch_elapsed)}
# Epoch 986, gen loss=4.747673988342285,disc loss=0.5259450674057007, {hms_string(epoch_elapsed)}
# Epoch 987, gen loss=5.467961311340332,disc loss=0.4674220681190491, {hms_string(epoch_elapsed)}
# Epoch 988, gen loss=4.8822784423828125,disc loss=0.4127871096134186, {hms_string(epoch_elapsed)}
# Epoch 989, gen loss=6.245475769042969,disc loss=0.18878304958343506, {hms_string(epoch_elapsed)}
# Epoch 990, gen loss=4.600358009338379,disc loss=0.27058935165405273, {hms_string(epoch_elapsed)}
# Epoch 991, gen loss=4.533909797668457,disc loss=0.23493504524230957, {hms_string(epoch_elapsed)}
# Epoch 992, gen loss=4.922167778015137,disc loss=0.1194608211517334, {hms_string(epoch_elapsed)}
# Epoch 993, gen loss=5.542990684509277,disc loss=0.18181505799293518, {hms_string(epoch_elapsed)}
# Epoch 994, gen loss=5.9416046142578125,disc loss=0.17457272112369537, {hms_string(epoch_elapsed)}
# Epoch 995, gen loss=4.231328964233398,disc loss=0.23678527772426605, {hms_string(epoch_elapsed)}
# Epoch 996, gen loss=5.950319290161133,disc loss=0.3241124153137207, {hms_string(epoch_elapsed)}
# Epoch 997, gen loss=4.3479228019714355,disc loss=0.3186928927898407, {hms_string(epoch_elapsed)}
# Epoch 998, gen loss=5.6920318603515625,disc loss=0.47549891471862793, {hms_string(epoch_elapsed)}
# Epoch 999, gen loss=5.558699607849121,disc loss=0.34727171063423157, {hms_string(epoch_elapsed)}
# Epoch 1000, gen loss=4.719354629516602,disc loss=0.33167386054992676, {hms_string(epoch_elapsed)}
# Training time: 0:09:18.02

# %%
a = imread('/content/drive/MyDrive/Datasets/banana-or-orange/training_set/output/train-1.png')
plt.imshow(a)

# %%
a = imread('/content/drive/MyDrive/Datasets/banana-or-orange/training_set/output/train-100.png')
plt.imshow(a)

# %%
a = imread('/content/drive/MyDrive/Datasets/banana-or-orange/training_set/output/train-250.png')
plt.imshow(a)

# %%
a = imread('/content/drive/MyDrive/Datasets/banana-or-orange/training_set/output/train-1000.png')
plt.imshow(a)

# %%
# generator.save(os.path.join(DATA_PATH,"tomato_generator.h5"))
