# %% [markdown]
# # Exercise 10.2: Building a Custom Layer

# %%
directory = "pneumonia-or-healthy"

# %%
import pathlib

# %%
path = pathlib.Path(directory)

# %%
train_dir = path / 'training_set'
validation_dir = path / 'test_set'

# %%
train_healthy_dir = train_dir / 'healthy'
train_pneumonia_dir = train_dir /'pneumonia'
validation_healthy_dir = validation_dir / 'healthy'
validation_pneumonia_dir = validation_dir / 'pneumonia'

# %%
import os

# %%
total_train = len(os.listdir(train_healthy_dir)) + \
              len(os.listdir(train_pneumonia_dir))
total_val = len(os.listdir(validation_healthy_dir)) + \
            len(os.listdir(validation_pneumonia_dir))

# %%
from tensorflow.keras.preprocessing.image\
    import ImageDataGenerator

# %%
train_image_generator = ImageDataGenerator(rescale=1./255)
validation_image_generator = ImageDataGenerator(rescale=1./255)

# %%
batch_size = 32
img_height = 100
img_width = 100

# %%
train_data_gen = train_image_generator.flow_from_directory\
                 (batch_size=batch_size, directory=train_dir, \
                  shuffle=True, \
                  target_size=(img_height, img_width), \
                  class_mode='binary')
# Out:
# Found 2750 images belonging to 2 classes.

# %%
val_data_gen = validation_image_generator.flow_from_directory\
               (batch_size=batch_size, directory=validation_dir, \
                target_size=(img_height, img_width), \
                class_mode='binary')
# Out:
# Found 1180 images belonging to 2 classes.

# %%
import matplotlib.pyplot as plt

for _ in range(5):
   img, label = train_data_gen.next()
   plt.imshow(img[0])
   plt.show()

# %%
import tensorflow as tf

# %%
from tensorflow.keras.layers import Input, Conv2D, ReLU, \
                                    BatchNormalization, Add, \
                                    AveragePooling2D, Flatten, Dense

# %%
def relu_batchnorm_layer(input):
    return BatchNormalization()(ReLU()(input))

# %%
def residual_block(input, filters: int, kernel_size: int = 3):
    int_output = Conv2D(filters=filters, kernel_size=kernel_size, \
                        strides=(2), \
                        padding="same")(input)
    int_output = relu_batchnorm_layer(int_output)
    int_output = Conv2D(filters=filters, kernel_size=kernel_size, \
                        padding="same")(int_output)

    int_output2 = Conv2D(filters=filters, kernel_size=1, strides=2,\
                        padding="same")(input)
    output = Add()([int_output2, int_output]) 

    output = relu_batchnorm_layer(output)
    return output

# %%
from tensorflow.keras.models import Model

# %%
inputs = Input(shape=(100, 100, 3))

# %%
t = BatchNormalization()(inputs)
t = Conv2D(kernel_size=3,\
           strides=1,\
           filters=32,\
           padding="same")(t)
t = relu_batchnorm_layer(t)

# %%
t = residual_block(t, filters=32)
    
t = AveragePooling2D(4)(t)
t = Flatten()(t)
outputs = Dense(1, activation='sigmoid')(t)

# %%
model = Model(inputs, outputs)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 100, 100, 3) 0
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 100, 100, 3)  12          input_1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 100, 100, 32) 896         batch_normalization[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, 100, 100, 32) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 100, 100, 32) 128         re_lu[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 50, 50, 32)   9248        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 50, 50, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 50, 50, 32)   128         re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 50, 50, 32)   1056        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 50, 50, 32)   9248        batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 50, 50, 32)   0           conv2d_3[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (None, 50, 50, 32)   0           add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 50, 50, 32)   128         re_lu_2[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 12, 12, 32)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 4608)         0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            4609        flatten[0][0]
# ==================================================================================================
# Total params: 25,453
# Trainable params: 25,255
# Non-trainable params: 198
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='adam',\
              loss=tf.keras.losses.binary_crossentropy,\
              metrics=['accuracy'])

# %%
history = model.fit(
    train_data_gen,
    steps_per_epoch=total_train // batch_size,
    epochs=5,
    validation_data=val_data_gen,
    validation_steps=total_val // batch_size
)
# Out:
# Epoch 1/5
# 85/85 [==============================] - 56s 630ms/step - loss: 0.5576 - accuracy: 0.7193 - val_loss: 0.8528 - val_accuracy: 0.4991
# Epoch 2/5
# 85/85 [==============================] - 46s 539ms/step - loss: 0.4889 - accuracy: 0.7642 - val_loss: 0.6130 - val_accuracy: 0.6432
# Epoch 3/5
# 85/85 [==============================] - 49s 574ms/step - loss: 0.4692 - accuracy: 0.7851 - val_loss: 0.6111 - val_accuracy: 0.6493
# Epoch 4/5
# 85/85 [==============================] - 45s 532ms/step - loss: 0.4483 - accuracy: 0.7840 - val_loss: 0.6523 - val_accuracy: 0.6328
# Epoch 5/5
# 85/85 [==============================] - 43s 505ms/step - loss: 0.4485 - accuracy: 0.7888 - val_loss: 0.6757 - val_accuracy: 0.6233
